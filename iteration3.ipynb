# %% [markdown]
# # Iteration 3

# %% [markdown]
# ## Introduction
#
# In my final project for "SML 301 - Data Intelligence: Modern Data Science Methods", I built a model to simultaneously count and classify selected animals from the *Wild* dataset.
#
# Diving into the literature long after the course had ended, I discovered a popular technique for enhancing the performance of CNNs. This is the "Squeeze-and-Excitation" Block introduced by [Hu et al.](
# https://doi.org/10.48550/arXiv.1709.01507
# ). As we move through the layers of a CNN, the number of channels grow and deeper features are extracted. When we pass an example into the model, every channel will feed its score into the head of the model to be transformed into an output. The problem occurs when we realize all of these channels are being calculated independently before being passed into the model.
#
# The way Hu et al. solve this problem is by adding a relatively tiny block between two CNN layers. The block *squeezes* the channels by projecting them into much fewer channels (often around a sixteenth of the original number).
#
#
# ## Introduction
#
# In this project we are interested in building a model that predicts the types of animals and the number of animals shown on images in the *Wild* dataset.  We will deviate from the approach used by [Parham et al.](https://ieeexplore.ieee.org/document/8354227) (the paper that we read in Precept 8) and employ a less complicated method inspired by the one used in [*Learn to Classify and Count: A Unified Framework for Object Classification and Counting*](https://dl.acm.org/doi/abs/10.1145/3191442.3191459) by Song and Qui instead.
#
#
# The unique names of the animals of interest are stored in the list `reduced_classes` below.  For each image, our goal is to identify the animals shown on the image and count how many there are.

# %%
from google.colab import drive
drive.mount('/content/drive')
_ = !unzip 'drive/My Drive/wild.zip' # "_ =" to suppress output
print('Complete')
# Out:
# Mounted at /content/drive
# Complete

# %%
reduced_classes = ['giraffe_reticulated','zebra_grevys','turtle_sea',
                   'zebra_plains','giraffe_masai', 'whale_fluke']

# %% [markdown]
# In Precept 10 we have created two collections of files to store the NumPy arrays:
#
# * `classify_arr`: with 0 and 1 elements classifying if an animal in `reduced_classes` shows up on the image
# * `count_arr`: with integers counting how many animals showing up on the image for each animal in `reduced_classes`

# %% [markdown]
# ## Question 1 Data quality check and EDA
#
# ### Part a
#
# Provide code and output to verify that you have 5,784 files in each of the *class_annotations* and *count_annotations* folders.
#
# Note: you might see 5,786 files in *class_annotations*.  However, if you check (and please do check this to be sure), you will see that the images ID's shown in *class_annotations* but not in *class_annotations* are `.DS_Store` and `..npy`.  You can ignore these two files.

# %%
import os
import numpy as np
import pandas as pd

import cv2 # an image and video processing library
from PIL import Image # Python Imaging Library

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Answers**

# %%
count_file_names = os.listdir('wild/count_annotations')
class_file_names = os.listdir('wild/class_annotations')
print(len(count_file_names))
print(len(class_file_names))
# Out:
# 5784
# 5784

# %% [markdown]
# ### Part c
#
# We would like to know how many animals show up in an image in general.
#
# (i.) What is the minimum and maximum of this number?
# (ii.) Please make a histogram for the number of animals in an image.
# (iii.) Is this distribution symmetric or does it have a long left/right tail?
#
# Hint: You can find sample code online on how  to make a histogram with a list, such as [this](https://stackoverflow.com/questions/33203645/how-to-plot-a-histogram-using-matplotlib-in-python-with-a-list-of-data).  Please modify the code to suit your needs.  Also, please use counts for the y-axis.  For all graphs that you make for this report, the plots should have clear labels and be informative.

# %% [markdown]
# **Answer**

# %%
num_obs = 5784
num_animals = [0] * num_obs
for idx, file in enumerate(count_file_names):
  array = np.load('wild/count_annotations/' + file)
  num_animals[idx] = array.sum()

# %% [markdown]
# (i)

# %%
print(f'max: {np.max(num_animals)}')
print(f'min: {np.min(num_animals)}')
# Out:
# max: 22.0
# min: 1.0

# %% [markdown]
# (ii)

# %%
plt.hist(num_animals, bins=22) # min=1 & max=22, so bins=22 shows all
plt.title('Number of Images with Specified Number of Animals')
plt.xlabel('Number of Animals')
plt.ylabel('Number of Images')
plt.show()

# %% [markdown]
# (iii) The above histogram has a long right tail. In fact, about 4000 of the 5784 images show just one animal, the minimum number.

# %% [markdown]
# ### Part d
#
# For each of the six species, create a histogram for the number of animals belonging to that species.  Instead of making 6 histograms, please make one histogram with stacked bins instead (see https://stackoverflow.com/questions/18449602/create-stacked-histogram-from-unequal-length-arrays). This makes it easier to compare the figures across all 6 categories.  Use counts for the y-axis.
#
# Among the 6 animals that we are interested, do any of them show up more frequently than other ones in the images? (You might need to make additional graph(s) that "zoom in" to certain region of the histogram if one single graph does not show all the details.)

# %% [markdown]
# **Answer**

# %%
num_animals = np.zeros((num_obs, 6))
for idx, file in enumerate(count_file_names):
  array = np.load('wild/count_annotations/' + file)
  for i in range(6):
    num_animals[idx, i] = array[i]

animal_stdevs = np.zeros(6)
print('='*30)
print('Standard Deviations')
print('='*30)
for i in range(6):
  animal_stdevs[i] = np.std(num_animals[:, i])
  print(f'{reduced_classes[i]}: {animal_stdevs[i]}')
print('='*30)
# Out:
# ==============================
# Standard Deviations
# ==============================
# giraffe_reticulated: 0.5898468065905499
# zebra_grevys: 1.0249837425546953
# turtle_sea: 0.3793641884667458
# zebra_plains: 1.535982358228098
# giraffe_masai: 0.6555192214336273
# whale_fluke: 0.38177452786234906
# ==============================

# %%
plt.hist(num_animals, bins=10, range=(1,10), stacked=True)
plt.legend(reduced_classes)
plt.title('Number of Images vs Number of Animals by Type')
plt.xlabel('Number of Animals')
plt.ylabel('Number of Images')
plt.show()

plt.hist(num_animals, bins=9, range=(2,10), stacked=True)
plt.legend(reduced_classes)
plt.title('Multiple Animals: Number of Images vs Number of Animals by Type')
plt.xlabel('Number of Animals')
plt.ylabel('Number of Images')
plt.show()

# %% [markdown]
# Fluke whales and sea turtles are almost always seen alone. Using the second graph, we see that both types of giraffes appear in groups of up to about 3-4. Likewise, we see both types of zebras appearing in groups of up to 7-9. For each species, there are pictures showing more, but numbers exceeding the upper range we give here are rare.

# %% [markdown]
# ## Question 2 Build the custom datasets object
#
# Recall that in Ch 8.7 we load the `MNIST` dataset into Python with the `torchvision.datasets` funtion/object and we further divide the dataset into training and validation batches by using the `torch.utils.data.DataLoader` function/object.  For this project, we will need to create the custom version of `torchvision.datasets`, because we are now dealing with a custom dataset that is not built in `PyTorch`.
#
# Please install the `opencv` library with the following code.  It is possible that you might also need to update your `pip` depending on its version.

# %%
# Install opencv for cv2:
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.25.2)

# %% [markdown]
# Please read [this tutorial](https://medium.com/analytics-vidhya/creating-a-custom-dataset-and-dataloader-in-pytorch-76f210a1df5d) on how to define a custom Dataset-class object.  Note that in place of the `glob()` function mentioned in the tutorial, we will use the `read_csv()` function from `pandas` instead.
#
# Here we will define a custom `Datasets` class.  The goal of our custom Dataset-class object is to read the images from the `JPEGImages` folder, resize the images to `img_size`, normalize the pixel values to range (0,1) for each image and then subtract the predefined mean, and divide by the predefined standard deviation. For targets corresponding to the classification and counting tasks, we would like to link the image with corresponding labels from the two .npy files created previously. Lastly, we will use the ID's provided in train.txt, val.txt, test.txt in the *Imagesets/Main* folder to divide the images for training, validation and testing purposes.
#
#
# The cell below provides the most of the code for creating the custom `Datasets` class. Please
#
# * replace all the directory paths below with paths that that are relevant to your computer system
# * fill in all the parts that labeled with `...`

# %%
from PIL import Image # Python Imaging Library
import cv2 # an image and video processing library
from torch.utils.data import Dataset
from torchvision import transforms
from torch.utils.data import DataLoader

class ClassifyCountDataset(Dataset):
    def __init__(self, dataset_type, img_size):

        self.img_path = 'wild/JPEGImages/'
        self.classify_path = 'wild/class_annotations/'
        self.count_path = 'wild/count_annotations/'

        # means and sds of images from ImageNet
        train_mean, train_sd = [0.4914, 0.4822, 0.4465], [0.247, 0.243, 0.261]
        self.transforms = transforms.Compose([
            transforms.Resize((img_size,img_size)),
            transforms.ToTensor(),
            transforms.Normalize(train_mean, train_sd)
        ])
        self.files = pd.read_csv('wild/ImageSets/Main/{}.txt'.format(dataset_type),header=None)[0].tolist()

    def __getitem__(self, index):
        file = self.files[index]
        img = self.transforms(Image.fromarray(cv2.imread(self.img_path+file+'.jpg').astype(np.uint8)))
        classify_target = torch.from_numpy(np.load(self.classify_path+file+'.npy'))

        normed_count = np.load(self.count_path+file+'.npy')/animal_stdevs
        count_target = torch.from_numpy(normed_count)

        return img, classify_target, count_target

    def __len__(self):
        return len(self.files)

# %% [markdown]
# Please answer the following questions about the `ClassifyCountDataset` class in your report to demonstrate that you understand the concepts explained in the tutorial:
#
# * Describe how `self.files` is calculated.  (Hint: The values that we will assign to `dataset_type` are usually one of these: 'test', 'train', 'trainval', 'val'.)
# * Describe the values `self.files` stores when `dataset_type` is set to 'test', and provide a few examples of these values.
# * Describe what steps we take to make `img` (i.e., what the original object is and what steps we take to process the original object) .
# * Describe what `classify_target` is and where it is from.

# %% [markdown]
# **Answers**

# %% [markdown]
# * In the folder wild/ImageSets/Main, there are four text files: test, train, trainval, and val. Inside of these files are strings (e.g., '2018_000118' is inside of test.txt). Then, self.files stores this string and sets dataset_type to the name of the .txt file it is in. For instance, '2018_000118' is stored in self.files and is put into the testing set, or more precisely, dataset_type is set to 'test' (because '2018_000118' is in test.txt).
# * The stored values of self.files with dataset_type = 'test' are the strings in wild/ImageSets/Main/test.txt, e.g. '2018_000118' and '2018_002280'.
# * Given the (string) value of self.files[-], we take the corresponding image in the JPEGImages folder. This is turned into an array (with 8-bit unsigned integer(uint8) values) and back to image (pixels with 3 uint8 values from 0-255 corresponding to rgb). Then, we then resize, turn it to a tensor with values in [0,1], and normalize according to the mean and std.
# * classify_target is the response array we will need for training and testing, the length 6 binary array telling us which species are in the image. Given the (string) value stored in self.files[-], we load the corresponding array in the class_annotations folder.

# %% [markdown]
# ## Question 3 Model architecture
#
# In this section we will define a convolutional neural network (CNN) that predicts the animals shown on a image, as well as the counts for each animal.  Because our CNN is supposed to produce two different kinds of outputs (animal class identifications and animal counts for each class) our CNN needs to be structured accordingly.
#
#
# Skim through the Introduction section and read section 3.1 of the paper [*Learn to Classify and Count: A Unified Framework for Object Classification and Counting*](https://dl.acm.org/doi/abs/10.1145/3191442.3191459) by Song and Qui.  This should give you a better idea of the structure of the network that we are going to build since our CNN will have an architecture similar to the network in the paper but simpler.  Following similar steps as the ones in the paper, we will build a CNN that has 2 output branches.  Just as the method described in the paper, we will train the upstream layers jointly.  However, instead of using the famous [VGG-16](https://builtin.com/machine-learning/vgg16) network architecture for the upstream layers, we will only borrow the architecture of the first few layers of VGG-16.  This is because VGG-16 has approximately 138 millions of hyperparameters and it will take a long time to train the entire VGG-16.
#
# The code in the next cell provides you the partial code for building the network for this project.  Please fill in the parts labeled with `...`.  There might be more than one entry needed for each `...`.  You can assume that the input images are of size 128 x 128.
#
# [Batch normalization](https://datahacker.rs/017-pytorch-how-to-apply-batch-normalization-in-pytorch/) is a popular technique used for improving deep neural network performance.  We will use the [torch.nn.BatchNorm2d() function](https://pytorch.org/docs/stable/generated/torch.nn.BatchNorm2d.html) to do batch normalization and keep the default values for its input arguments.  Note that batch normalization does not change the shape of its input or output.
#
# Just a reminder: The `nn.Sequential()` function was discussed in Chapter 8.5 of the lecture notes.
#
# I have described the architecture of the network below:
#
# For **block 1**:
#
# * first layer:
#     + a convolutional layer with 64 channels with (5 x 5) filters (kernels) with no padding; batch normalization; activation function: relu.
#
# * second layer:
#     + a convolutional layer with 64 channels with (5 x 5) filters; batch normalization; activation function: relu.
#     + a maximum pooling layer with (2 x 2 filter), each time move the filter 2 steps when moving horizontally and vertically, no padding
#
#
# For **block 2**:
#
# * first layer:
#     + a convolutional layer with 128 channels with (5 x 5) filters with no padding; batch normalization; activation function: relu.
#
# * second layer:
#     + a convolutional layer with 128 channels with (5 x 5) filters with no padding; batch normalization; activation function: relu.
#     + a maximum pooling layer with (2 x 2 filter), each time move the filter 2 steps when moving horizontally and vertically, no padding
#
#
# For each of the **branches**
#
# The following two layers are coded with the *self.branches.append()* function
#
# * first layer:
#     + a convolutional layer with 128 channels with (3 x 3) filters with one row/column of zeros added to all four sides of the input; batch normalization; activation function: relu.
#
# * second layer:
#     + a convolutional layer with 128 channels with (3 x 3) filters with one row/column of zeros added to all four sides of the input; batch normalization; activation function: relu.
#     + a maximum pooling layer with (2 x 2 filter), each time move the filter 2 steps when moving horizontally and vertically, no padding
#
# Third layer: flatten
#
# The following layers are coded with the *self.outputs.append()* function
#
#
# * fourth layer:
#     + dense layer with 256 neurons; activation function: relu
#     + dropout rate: 50%
#
#
# * output layer.

# %%
import torch
import torch.nn as nn

# %%
class SqueezeExcitation(nn.Module):
  def __init__(self, num_channels, r=16):
    super(SqueezeExcitation, self).__init__()
    self.squeeze = nn.AdaptiveAvgPool2d(1)
    self.excitation = nn.Sequential(
        nn.Linear(num_channels, num_channels//r, bias=False),
        nn.ReLU(inplace=True),
        nn.Linear(num_channels//r, num_channels, bias=False),
        nn.Sigmoid()
    )

  def forward(self, x):
    bs, num_channels, _, _ = x.shape
    y = self.squeeze(x).view(bs, num_channels)
    y = self.excitation(y).view(bs, num_channels, 1, 1)
    return x * y.expand_as(x)

class VGG16Counting(nn.Module):
    def __init__(self, num_classes=...):
        super(VGG16Counting, self).__init__()
        # 128 x 128 object
        self.block1 = nn.Sequential(nn.Conv2d(3, 64, 5),
                                    nn.BatchNorm2d(64), nn.ReLU(),
                                    nn.Conv2d(64, 64, 5),
                                    nn.BatchNorm2d(64), nn.ReLU(),
                                    nn.MaxPool2d(2))
        # 60 x 60 object
        self.block2 = nn.Sequential(nn.Conv2d(64, 128, 5),
                                    nn.BatchNorm2d(128), nn.ReLU(),
                                    nn.Conv2d(128, 128, 5),
                                    nn.BatchNorm2d(128), nn.ReLU(),
                                    nn.MaxPool2d(2))
        # 26 x 26 object

        self.se = SqueezeExcitation(128)

        #### create 2 branches below ####

        # initialize two PyTorch lists;
        # ModuleList() is like the native python list container [], but it is for PyTorch.
        self.branches, self.outputs = nn.ModuleList(), nn.ModuleList()
        for _ in range(2):
            # 26 x 26 object
            self.branches.append(nn.Sequential(nn.Conv2d(128, 128, 3, padding=1),
                                               nn.BatchNorm2d(128), nn.ReLU(),
                                               nn.Conv2d(128, 128, 3, padding=1),
                                               nn.BatchNorm2d(128), nn.ReLU(),
                                               nn.MaxPool2d(2)))

            # 13 x 13 object with 128 channels
            self.outputs.append(nn.Sequential(nn.Linear(13 * 13 * 128 * 2, 256),
                                          nn.ReLU(), nn.Dropout(0.2),
                                          nn.Linear(256, 6)))

    def forward(self, x):
      x = self.block1(x)
      x = self.block2(x)
      x = self.se(x)

      x = torch.cat([torch.flatten(branch(x), start_dim=1) for branch in self.branches], 1)

      outputs = [output(x) for output in self.outputs]

      return outputs

# %% [markdown]
# ## Question 4 Model training
#
# ### Part a
#
# In this part of the question we will define the `train()` function for training the model.  Please fill in the parts labeled with `...` for `train()`. A [confusion matrix](https://www.geeksforgeeks.org/confusion-matrix-machine-learning/) is often useful for evaluating the performance of a model.
#
# Besides filling in the places labeled with `...`, modify the `train()` function so that we can later make plots to show that we did not overfit the model (see Part e).

# %%
from sklearn.metrics import multilabel_confusion_matrix, mean_squared_error, roc_auc_score

# training loop over batches; forward and backward propagation
def train_batch_loop(model, optimizer, train_dataloader, device, mse, bce):
    for _, (imgs,targets_classify,targets_counts) in enumerate(train_dataloader):
      imgs = imgs.to(device)
      targets_classify = targets_classify.to(device).float()
      targets_counts = targets_counts.to(device).float()

      outputs = model(imgs)
      bce_loss = bce(outputs[0], targets_classify)
      mse_loss = mse(outputs[1], targets_counts)
      loss = bce_loss + 10 * mse_loss # bce about 10x more than mse in this case
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
    return

# classwise errors for classification problem
def eval_classify(targets_classify, preds_classify):
    targets_classify_array = targets_classify.cpu().detach().numpy()
    preds_classify_array = preds_classify.cpu().detach().numpy()

    confusion_matrix = multilabel_confusion_matrix(targets_classify_array,
                                                   preds_classify_array)

    classwise_precisions = []
    for i in range(6):
      positives_i = confusion_matrix[i, 1, 1] + confusion_matrix[i, 0, 1]
      precision_i = confusion_matrix[i, 1, 1] / positives_i # TP / (TP + FP)
      classwise_precisions.append(np.round(precision_i, 3))
    print(f'Average precision by class: {classwise_precisions}')

    roc_auc_scores = [roc_auc_score(targets_classify_array[:,i],
                                    preds_classify_array[:,i])
                      for i in range(6)]
    return roc_auc_scores

# classwise errors for counting problem
def eval_count(targets_count, preds_count):
    targets_count_array = targets_count.cpu().detach().numpy()
    preds_count_array = preds_count.cpu().detach().numpy()

    relrmse_classwise = []
    for i in range(6):
      # renormalize for fair judging
      preds = preds_count_array[:,i] * animal_stdevs[i]
      trgts = targets_count_array[:,i] * animal_stdevs[i]
      relrmse = np.sqrt(np.mean(np.square(preds - trgts) /
                        (preds + 1)))
      relrmse_classwise.append(relrmse)

    avg_relrmse = sum(relrmse_classwise) / len(relrmse_classwise)
    print(f'Mean Relative Root Mean Squared Error: {np.round(avg_relrmse, 4)}')
    return relrmse_classwise

# evaluation loop over batches
def eval_batch_loop(model, validation_dataloader, device):
    total_targets_classify = torch.Tensor().to(device)
    total_preds_classify = torch.Tensor().to(device)
    total_targets_count = torch.Tensor().to(device)
    total_preds_count = torch.Tensor().to(device)
    for _, (imgs, targets_classify, targets_counts) in enumerate(validation_dataloader):
      imgs = imgs.to(device)
      targets_classify = targets_classify.to(device).int()
      targets_counts = targets_counts.to(device).int()
      outputs = model(imgs)

      total_targets_classify = torch.cat((total_targets_classify,targets_classify),dim=0)
      total_preds_classify = torch.cat((total_preds_classify,torch.round(nn.Sigmoid()(outputs[0])).int()),dim=0)

      total_targets_count = torch.cat((total_targets_count,targets_counts),dim=0)
      total_preds_count = torch.cat((total_preds_count,torch.round(nn.ReLU()(outputs[1])).int()),dim=0)

    class_roc_auc = eval_classify(total_targets_classify,
                                  total_preds_classify)
    class_relrmse = eval_count(total_targets_count, total_preds_count)
    return class_roc_auc, class_relrmse

# %%
def train(model, optimizer, train_dataloader, val_dataloader, num_epochs=100):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    mse = nn.MSELoss()
    bce = nn.BCEWithLogitsLoss()

    epoch_roc_aucs = np.zeros((num_epochs, 6))
    epoch_relrmses = np.zeros((num_epochs, 6))

    for epoch in range(1, num_epochs + 1):
      print('='*70)
      print(f'Epoch: {epoch}')
      print('='*70)

      # forward & backward propagation in batch loop
      model.train()  # set model to training mode
      train_batch_loop(model, optimizer, train_dataloader, device, mse, bce)

      # save model weights
      if epoch % 5 == 0:
        torch.save(model.state_dict(),
                   f'drive/My Drive/Iteration 3 Full/epoch_{epoch}.pth')

      # evaluating model at current epoch after training
      model.eval() # set model to evaluation mode
      roc_aucs, relrmses = eval_batch_loop(model, val_dataloader, device)

      epoch_roc_aucs[epoch - 1, :] = roc_aucs
      epoch_relrmses[epoch - 1, :] = relrmses

    return epoch_roc_aucs, epoch_relrmses

# %% [markdown]
# ### Part b
#
# Note that the loss function is defined to be the sum of two loss functions: `MSELoss()` and `BCEWithLogitsLoss()`.  This is inspired by the loss function used in the paper by Song and Qui.
# Justify why it is reasonable to use the two loss functions `MSELoss()` and `BCEWithLogitsLoss()`.

# %% [markdown]
# **Answer**
#
# First of all, we have two different outputs, and these outputs differ in nature. When classifying, we are predicting a binary response, so we have values between 0 and 1. A natural error measurement is then the standard binary cross-entropy. Likewise, when predicting the number of each animal in an image, we are predicting a numerical response. In this case, it makes sense to use the standard MSE.

# %% [markdown]
# ### Part c
#
# Note that the use of `BCEWithLogitsLoss()` (instead of `nn.CrossEntropyLoss()`) means that we use the sigmoid function (instead of a softmax function) as the activation function for the last layer for the classification branch.
#
# However, there are 6 neurons in the output layer for the classification branch, one for each class.  For the examples that we have seen in this course, usually when there are more than 2 classes, we use a softmax function on the last layer, and only use the sigmoid function for binary classification.  Explain why the use of the sigmoid function is appropriate here.  (Hint: Suppose that the values (before applying the activation function) for the 6 neurons on the last layer are $z_1, z_2, ..., z_6$.  If we applied the softmax function to these values, the 6 values after the softmax transformation would sum up to be what value? What would be the implied relationship between the classes in this case?  Please include the answers to these questions in your report too.)

# %% [markdown]
# **Answer**
#
# If we used softmax, then the values of the 'probabilities' of each species being in the image add to 1. This would be great if each image contained exactly one species, but this is not true for our dataset. Indeed, there are plenty of images with more than one species. The sigmoid function allows the likelihood of a certain species being in the image to be measured independently of the others.

# %% [markdown]
# ### Part d
#
# Fill in the missing parts below to load the data.

# %%
# Create dataloader
train_dataset = ClassifyCountDataset(dataset_type = 'train', img_size = 128)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = ClassifyCountDataset(dataset_type = 'val', img_size = 128)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# We initiate the model and define the optimizer below.

# %%
import torch.optim as optim

# %%
torch.manual_seed(2023)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# initiate model
model = VGG16Counting(num_classes=6).to(device)

# Create optimizer
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# ### Part e
#
# Train the model and make sure that your champion model does not overfit.  Please provide graphs to show that you did not overfit your model.  You do not need to tune any hyperparameters, except for the number of epochs.

# %% [markdown]
# **Hyperparameter Selection**

# %%
roc_aucs_by_epoch, mses_by_epoch = train(model, optimizer, train_dataloader, val_dataloader)
roc_aucs_by_epoch = np.array(roc_aucs_by_epoch)
mses_by_epoch = np.array(mses_by_epoch)
np.save('drive/My Drive/Iteration 3/roc_aucs.npy', roc_aucs_by_epoch)
np.save('drive/My Drive/Iteration 3/mses.npy', mses_by_epoch)
# Out:
# ======================================================================
# Epoch: 1
# ======================================================================
# Average precision by class: [0.662, 0.727, 0.973, 0.809, 0.69, 0.905]
# Mean Relative Root Mean Squared Error: 0.5367
# ======================================================================
# Epoch: 2
# ======================================================================
# Average precision by class: [0.627, 0.75, 0.989, 0.821, 0.667, 0.974]
# Mean Relative Root Mean Squared Error: 0.5336
# ======================================================================
# Epoch: 3
# ======================================================================
# Average precision by class: [0.891, 0.721, 0.989, 0.78, 0.647, 0.948]
# Mean Relative Root Mean Squared Error: 0.5203
# ======================================================================
# Epoch: 4
# ======================================================================
# Average precision by class: [0.956, 0.821, 1.0, 0.919, 0.572, 0.9]
# Mean Relative Root Mean Squared Error: 0.5295
# ======================================================================
# Epoch: 5
# ======================================================================
# Average precision by class: [0.707, 0.825, 0.979, 0.771, 0.785, 0.978]
# Mean Relative Root Mean Squared Error: 0.5156
# ======================================================================
# Epoch: 6
# ======================================================================
# Average precision by class: [0.934, 0.766, 0.989, 0.971, 0.68, 0.974]
# Mean Relative Root Mean Squared Error: 0.4956
# ======================================================================
# Epoch: 7
# ======================================================================
# Average precision by class: [0.92, 0.914, 0.989, 0.871, 0.568, 0.954]
# Mean Relative Root Mean Squared Error: 0.4787
# ======================================================================
# Epoch: 8
# ======================================================================
# Average precision by class: [0.867, 0.73, 0.985, 0.882, 0.78, 1.0]
# Mean Relative Root Mean Squared Error: 0.4575
# ======================================================================
# Epoch: 9
# ======================================================================
# Average precision by class: [0.762, 0.903, 0.984, 0.899, 0.839, 0.954]
# Mean Relative Root Mean Squared Error: 0.4633
# ======================================================================
# Epoch: 10
# ======================================================================
# Average precision by class: [0.788, 0.85, 0.984, 0.906, 0.799, 0.979]
# Mean Relative Root Mean Squared Error: 0.4456
# ======================================================================
# Epoch: 11
# ======================================================================
# Average precision by class: [0.896, 0.917, 0.93, 0.851, 0.793, 0.973]
# Mean Relative Root Mean Squared Error: 0.4693
# ======================================================================
# Epoch: 12
# ======================================================================
# Average precision by class: [0.852, 0.878, 0.969, 0.953, 0.656, 0.989]
# Mean Relative Root Mean Squared Error: 0.4379
# ======================================================================
# Epoch: 13
# ======================================================================
# Average precision by class: [0.885, 0.926, 0.965, 0.892, 0.648, 0.949]
# Mean Relative Root Mean Squared Error: 0.4556
# ======================================================================
# Epoch: 14
# ======================================================================
# Average precision by class: [0.912, 0.893, 0.932, 0.943, 0.736, 0.984]
# Mean Relative Root Mean Squared Error: 0.4301
# ======================================================================
# Epoch: 15
# ======================================================================
# Average precision by class: [0.833, 0.742, 0.984, 0.885, 0.923, 1.0]
# Mean Relative Root Mean Squared Error: 0.434
# ======================================================================
# Epoch: 16
# ======================================================================
# Average precision by class: [0.93, 0.843, 0.974, 0.855, 0.736, 0.995]
# Mean Relative Root Mean Squared Error: 0.4224
# ======================================================================
# Epoch: 17
# ======================================================================
# Average precision by class: [0.915, 0.738, 0.97, 0.911, 0.856, 0.989]
# Mean Relative Root Mean Squared Error: 0.4293
# ======================================================================
# Epoch: 18
# ======================================================================
# Average precision by class: [0.87, 0.876, 0.984, 0.873, 0.831, 0.974]
# Mean Relative Root Mean Squared Error: 0.4467
# ======================================================================
# Epoch: 19
# ======================================================================
# Average precision by class: [0.921, 0.778, 0.984, 0.866, 0.791, 0.995]
# Mean Relative Root Mean Squared Error: 0.4517
# ======================================================================
# Epoch: 20
# ======================================================================
# Average precision by class: [0.885, 0.887, 0.951, 0.957, 0.865, 0.974]
# Mean Relative Root Mean Squared Error: 0.4356
# ======================================================================
# Epoch: 21
# ======================================================================
# Average precision by class: [0.884, 0.833, 0.984, 0.878, 0.829, 0.979]
# Mean Relative Root Mean Squared Error: 0.4374
# ======================================================================
# Epoch: 22
# ======================================================================
# Average precision by class: [0.966, 0.849, 0.989, 0.883, 0.733, 0.964]
# Mean Relative Root Mean Squared Error: 0.4498
# ======================================================================
# Epoch: 23
# ======================================================================
# Average precision by class: [0.869, 0.928, 0.979, 0.916, 0.879, 0.995]
# Mean Relative Root Mean Squared Error: 0.4187
# ======================================================================
# Epoch: 24
# ======================================================================
# Average precision by class: [0.85, 0.901, 0.989, 0.833, 0.865, 0.995]
# Mean Relative Root Mean Squared Error: 0.4333
# ======================================================================
# Epoch: 25
# ======================================================================
# Average precision by class: [0.866, 0.773, 0.989, 0.931, 0.904, 1.0]
# Mean Relative Root Mean Squared Error: 0.439
# ======================================================================
# Epoch: 26
# ======================================================================
# Average precision by class: [0.868, 0.825, 0.974, 0.867, 0.932, 0.96]
# Mean Relative Root Mean Squared Error: 0.4511
# ======================================================================
# Epoch: 27
# ======================================================================
# Average precision by class: [0.91, 0.757, 0.995, 0.91, 0.869, 0.984]
# Mean Relative Root Mean Squared Error: 0.4345
# ======================================================================
# Epoch: 28
# ======================================================================
# Average precision by class: [0.852, 0.885, 0.99, 0.871, 0.912, 0.989]
# Mean Relative Root Mean Squared Error: 0.4278
# ======================================================================
# Epoch: 29
# ======================================================================
# Average precision by class: [0.874, 0.883, 0.995, 0.921, 0.88, 0.974]
# Mean Relative Root Mean Squared Error: 0.4145
# ======================================================================
# Epoch: 30
# ======================================================================
# Average precision by class: [0.868, 0.815, 0.989, 0.915, 0.912, 0.964]
# Mean Relative Root Mean Squared Error: 0.4286
# ======================================================================
# Epoch: 31
# ======================================================================
# Average precision by class: [0.907, 0.923, 0.974, 0.801, 0.827, 1.0]
# Mean Relative Root Mean Squared Error: 0.4391
# ======================================================================
# Epoch: 32
# ======================================================================
# Average precision by class: [0.872, 0.923, 0.995, 0.871, 0.921, 1.0]
# Mean Relative Root Mean Squared Error: 0.4413
# ======================================================================
# Epoch: 33
# ======================================================================
# Average precision by class: [0.865, 0.831, 0.984, 0.888, 0.916, 1.0]
# Mean Relative Root Mean Squared Error: 0.4203
# ======================================================================
# Epoch: 34
# ======================================================================
# Average precision by class: [0.905, 0.81, 0.984, 0.935, 0.841, 0.974]
# Mean Relative Root Mean Squared Error: 0.4427
# ======================================================================
# Epoch: 35
# ======================================================================
# Average precision by class: [0.917, 0.868, 0.97, 0.81, 0.91, 0.979]
# Mean Relative Root Mean Squared Error: 0.4432
# ======================================================================
# Epoch: 36
# ======================================================================
# Average precision by class: [0.887, 0.886, 0.99, 0.891, 0.924, 0.989]
# Mean Relative Root Mean Squared Error: 0.4197
# ======================================================================
# Epoch: 37
# ======================================================================
# Average precision by class: [0.873, 0.854, 0.995, 0.899, 0.832, 0.995]
# Mean Relative Root Mean Squared Error: 0.4266
# ======================================================================
# Epoch: 38
# ======================================================================
# Average precision by class: [0.872, 0.822, 0.974, 0.903, 0.893, 0.984]
# Mean Relative Root Mean Squared Error: 0.4327
# ======================================================================
# Epoch: 39
# ======================================================================
# Average precision by class: [0.864, 0.86, 0.97, 0.867, 0.958, 0.974]
# Mean Relative Root Mean Squared Error: 0.447
# ======================================================================
# Epoch: 40
# ======================================================================
# Average precision by class: [0.916, 0.87, 0.984, 0.868, 0.856, 0.99]
# Mean Relative Root Mean Squared Error: 0.4263
# ======================================================================
# Epoch: 41
# ======================================================================
# Average precision by class: [0.858, 0.84, 0.99, 0.924, 0.886, 0.964]
# Mean Relative Root Mean Squared Error: 0.4291
# ======================================================================
# Epoch: 42
# ======================================================================
# Average precision by class: [0.865, 0.908, 0.995, 0.792, 0.936, 0.984]
# Mean Relative Root Mean Squared Error: 0.4394
# ======================================================================
# Epoch: 43
# ======================================================================
# Average precision by class: [0.913, 0.902, 0.969, 0.935, 0.742, 0.995]
# Mean Relative Root Mean Squared Error: 0.4346
# ======================================================================
# Epoch: 44
# ======================================================================
# Average precision by class: [0.856, 0.916, 0.98, 0.817, 0.86, 0.979]
# Mean Relative Root Mean Squared Error: 0.4213
# ======================================================================
# Epoch: 45
# ======================================================================
# Average precision by class: [0.895, 0.885, 0.99, 0.912, 0.85, 0.984]
# Mean Relative Root Mean Squared Error: 0.4167
# ======================================================================
# Epoch: 46
# ======================================================================
# Average precision by class: [0.868, 0.888, 1.0, 0.912, 0.832, 0.979]
# Mean Relative Root Mean Squared Error: 0.4389
# ======================================================================
# Epoch: 47
# ======================================================================
# Average precision by class: [0.871, 0.904, 0.974, 0.856, 0.91, 0.979]
# Mean Relative Root Mean Squared Error: 0.4297
# ======================================================================
# Epoch: 48
# ======================================================================
# Average precision by class: [0.889, 0.799, 1.0, 0.836, 0.932, 0.984]
# Mean Relative Root Mean Squared Error: 0.4344
# ======================================================================
# Epoch: 49
# ======================================================================
# Average precision by class: [0.9, 0.916, 0.99, 0.906, 0.881, 0.95]
# Mean Relative Root Mean Squared Error: 0.4364
# ======================================================================
# Epoch: 50
# ======================================================================
# Average precision by class: [0.9, 0.82, 0.965, 0.864, 0.905, 0.995]
# Mean Relative Root Mean Squared Error: 0.4098
# ======================================================================
# Epoch: 51
# ======================================================================
# Average precision by class: [0.886, 0.924, 0.98, 0.91, 0.857, 0.989]
# Mean Relative Root Mean Squared Error: 0.4139
# ======================================================================
# Epoch: 52
# ======================================================================
# Average precision by class: [0.886, 0.893, 0.995, 0.833, 0.886, 0.979]
# Mean Relative Root Mean Squared Error: 0.439
# ======================================================================
# Epoch: 53
# ======================================================================
# Average precision by class: [0.9, 0.898, 0.99, 0.926, 0.8, 1.0]
# Mean Relative Root Mean Squared Error: 0.4153
# ======================================================================
# Epoch: 54
# ======================================================================
# Average precision by class: [0.883, 0.892, 0.975, 0.918, 0.87, 0.989]
# Mean Relative Root Mean Squared Error: 0.4277
# ======================================================================
# Epoch: 55
# ======================================================================
# Average precision by class: [0.934, 0.939, 0.98, 0.868, 0.793, 0.979]
# Mean Relative Root Mean Squared Error: 0.4353
# ======================================================================
# Epoch: 56
# ======================================================================
# Average precision by class: [0.894, 0.877, 0.985, 0.869, 0.888, 0.984]
# Mean Relative Root Mean Squared Error: 0.3981
# ======================================================================
# Epoch: 57
# ======================================================================
# Average precision by class: [0.872, 0.873, 0.99, 0.906, 0.884, 1.0]
# Mean Relative Root Mean Squared Error: 0.4044
# ======================================================================
# Epoch: 58
# ======================================================================
# Average precision by class: [0.886, 0.82, 0.985, 0.949, 0.882, 0.96]
# Mean Relative Root Mean Squared Error: 0.4266
# ======================================================================
# Epoch: 59
# ======================================================================
# Average precision by class: [0.889, 0.924, 0.99, 0.896, 0.814, 0.989]
# Mean Relative Root Mean Squared Error: 0.4242
# ======================================================================
# Epoch: 60
# ======================================================================
# Average precision by class: [0.883, 0.861, 0.965, 0.874, 0.896, 1.0]
# Mean Relative Root Mean Squared Error: 0.4139
# ======================================================================
# Epoch: 61
# ======================================================================
# Average precision by class: [0.921, 0.819, 0.956, 0.87, 0.89, 0.984]
# Mean Relative Root Mean Squared Error: 0.4258
# ======================================================================
# Epoch: 62
# ======================================================================
# Average precision by class: [0.934, 0.871, 0.995, 0.874, 0.87, 0.964]
# Mean Relative Root Mean Squared Error: 0.407
# ======================================================================
# Epoch: 63
# ======================================================================
# Average precision by class: [0.954, 0.845, 0.97, 0.897, 0.816, 0.989]
# Mean Relative Root Mean Squared Error: 0.4198
# ======================================================================
# Epoch: 64
# ======================================================================
# Average precision by class: [0.895, 0.864, 0.99, 0.857, 0.903, 0.989]
# Mean Relative Root Mean Squared Error: 0.457
# ======================================================================
# Epoch: 65
# ======================================================================
# Average precision by class: [0.89, 0.899, 0.995, 0.843, 0.917, 0.995]
# Mean Relative Root Mean Squared Error: 0.4125
# ======================================================================
# Epoch: 66
# ======================================================================
# Average precision by class: [0.908, 0.866, 0.99, 0.826, 0.928, 0.989]
# Mean Relative Root Mean Squared Error: 0.4438
# ======================================================================
# Epoch: 67
# ======================================================================
# Average precision by class: [0.877, 0.872, 0.985, 0.876, 0.894, 0.974]
# Mean Relative Root Mean Squared Error: 0.4169
# ======================================================================
# Epoch: 68
# ======================================================================
# Average precision by class: [0.899, 0.909, 0.989, 0.897, 0.91, 0.96]
# Mean Relative Root Mean Squared Error: 0.4318
# ======================================================================
# Epoch: 69
# ======================================================================
# Average precision by class: [0.938, 0.924, 0.975, 0.924, 0.769, 0.979]
# Mean Relative Root Mean Squared Error: 0.4327
# ======================================================================
# Epoch: 70
# ======================================================================
# Average precision by class: [0.887, 0.909, 0.99, 0.887, 0.91, 0.99]
# Mean Relative Root Mean Squared Error: 0.4268
# ======================================================================
# Epoch: 71
# ======================================================================
# Average precision by class: [0.797, 0.866, 0.984, 0.799, 0.933, 1.0]
# Mean Relative Root Mean Squared Error: 0.4085
# ======================================================================
# Epoch: 72
# ======================================================================
# Average precision by class: [0.886, 0.916, 0.985, 0.889, 0.897, 0.974]
# Mean Relative Root Mean Squared Error: 0.4119
# ======================================================================
# Epoch: 73
# ======================================================================
# Average precision by class: [0.921, 0.78, 0.995, 0.913, 0.867, 1.0]
# Mean Relative Root Mean Squared Error: 0.4233
# ======================================================================
# Epoch: 74
# ======================================================================
# Average precision by class: [0.929, 0.854, 0.933, 0.904, 0.934, 0.974]
# Mean Relative Root Mean Squared Error: 0.4388
# ======================================================================
# Epoch: 75
# ======================================================================
# Average precision by class: [0.944, 0.833, 0.985, 0.843, 0.901, 0.984]
# Mean Relative Root Mean Squared Error: 0.4102
# ======================================================================
# Epoch: 76
# ======================================================================
# Average precision by class: [0.83, 0.974, 0.97, 0.771, 0.937, 0.99]
# Mean Relative Root Mean Squared Error: 0.401
# ======================================================================
# Epoch: 77
# ======================================================================
# Average precision by class: [0.894, 0.975, 0.995, 0.828, 0.867, 0.995]
# Mean Relative Root Mean Squared Error: 0.4087
# ======================================================================
# Epoch: 78
# ======================================================================
# Average precision by class: [0.87, 0.856, 0.995, 0.945, 0.927, 0.989]
# Mean Relative Root Mean Squared Error: 0.4194
# ======================================================================
# Epoch: 79
# ======================================================================
# Average precision by class: [0.916, 0.879, 0.99, 0.904, 0.904, 0.979]
# Mean Relative Root Mean Squared Error: 0.4096
# ======================================================================
# Epoch: 80
# ======================================================================
# Average precision by class: [0.901, 0.869, 0.99, 0.914, 0.896, 0.989]
# Mean Relative Root Mean Squared Error: 0.4127
# ======================================================================
# Epoch: 81
# ======================================================================
# Average precision by class: [0.944, 0.913, 0.98, 0.893, 0.844, 0.995]
# Mean Relative Root Mean Squared Error: 0.4199
# ======================================================================
# Epoch: 82
# ======================================================================
# Average precision by class: [0.909, 0.929, 0.99, 0.867, 0.797, 0.984]
# Mean Relative Root Mean Squared Error: 0.4171
# ======================================================================
# Epoch: 83
# ======================================================================
# Average precision by class: [0.881, 0.963, 0.995, 0.879, 0.848, 0.995]
# Mean Relative Root Mean Squared Error: 0.4052
# ======================================================================
# Epoch: 84
# ======================================================================
# Average precision by class: [0.922, 0.856, 0.99, 0.887, 0.857, 0.995]
# Mean Relative Root Mean Squared Error: 0.4223
# ======================================================================
# Epoch: 85
# ======================================================================
# Average precision by class: [0.865, 0.843, 0.99, 0.885, 0.935, 0.995]
# Mean Relative Root Mean Squared Error: 0.4096
# ======================================================================
# Epoch: 86
# ======================================================================
# Average precision by class: [0.906, 0.874, 0.98, 0.893, 0.902, 0.974]
# Mean Relative Root Mean Squared Error: 0.421
# ======================================================================
# Epoch: 87
# ======================================================================
# Average precision by class: [0.864, 0.81, 0.99, 0.919, 0.917, 1.0]
# Mean Relative Root Mean Squared Error: 0.4067
# ======================================================================
# Epoch: 88
# ======================================================================
# Average precision by class: [0.829, 0.906, 0.98, 0.927, 0.873, 0.995]
# Mean Relative Root Mean Squared Error: 0.41
# ======================================================================
# Epoch: 89
# ======================================================================
# Average precision by class: [0.961, 0.816, 1.0, 0.901, 0.872, 0.918]
# Mean Relative Root Mean Squared Error: 0.4441
# ======================================================================
# Epoch: 90
# ======================================================================
# Average precision by class: [0.886, 0.823, 0.985, 0.896, 0.914, 0.984]
# Mean Relative Root Mean Squared Error: 0.4244
# ======================================================================
# Epoch: 91
# ======================================================================
# Average precision by class: [0.877, 0.907, 0.99, 0.963, 0.881, 0.995]
# Mean Relative Root Mean Squared Error: 0.4213
# ======================================================================
# Epoch: 92
# ======================================================================
# Average precision by class: [0.924, 0.812, 0.995, 0.886, 0.894, 0.974]
# Mean Relative Root Mean Squared Error: 0.4293
# ======================================================================
# Epoch: 93
# ======================================================================
# Average precision by class: [0.896, 0.866, 0.995, 0.881, 0.868, 0.995]
# Mean Relative Root Mean Squared Error: 0.4364
# ======================================================================
# Epoch: 94
# ======================================================================
# Average precision by class: [0.916, 0.889, 0.995, 0.887, 0.86, 0.995]
# Mean Relative Root Mean Squared Error: 0.4214
# ======================================================================
# Epoch: 95
# ======================================================================
# Average precision by class: [0.864, 0.948, 0.97, 0.887, 0.883, 0.995]
# Mean Relative Root Mean Squared Error: 0.4194
# ======================================================================
# Epoch: 96
# ======================================================================
# Average precision by class: [0.908, 0.79, 0.98, 0.918, 0.869, 0.989]
# Mean Relative Root Mean Squared Error: 0.4015
# ======================================================================
# Epoch: 97
# ======================================================================
# Average precision by class: [0.915, 0.934, 0.99, 0.89, 0.76, 1.0]
# Mean Relative Root Mean Squared Error: 0.4087
# ======================================================================
# Epoch: 98
# ======================================================================
# Average precision by class: [0.877, 0.9, 0.979, 0.898, 0.951, 0.99]
# Mean Relative Root Mean Squared Error: 0.422
# ======================================================================
# Epoch: 99
# ======================================================================
# Average precision by class: [0.894, 0.919, 0.99, 0.924, 0.832, 0.99]
# Mean Relative Root Mean Squared Error: 0.4066
# ======================================================================
# Epoch: 100
# ======================================================================
# Average precision by class: [0.846, 0.958, 0.995, 0.912, 0.899, 0.974]
# Mean Relative Root Mean Squared Error: 0.4103

# %%
roc_aucs_by_epoch = np.load('drive/My Drive/Iteration 3/roc_aucs.npy')
mses_by_epoch = np.load('drive/My Drive/Iteration 3/mses.npy')

# %%
# relrmses
for i in range(6):
  plt.plot(np.arange(1,101), mses_by_epoch[:,i], label = reduced_classes[i])
plt.legend()
plt.title('RelRMSE vs Epoch by Species')
plt.xlabel('Epoch')
plt.ylabel('Relative RMSE')
plt.show()

# avg relrmse
relrmses = np.mean(mses_by_epoch, axis=1)
plt.plot(np.arange(1,101), relrmses)
plt.title('Averge RelRMSE vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Relative RMSE')
plt.show()

# roc aucs
for i in range(6):
  plt.plot(np.arange(1,101), roc_aucs_by_epoch[:,i], label = reduced_classes[i])
plt.legend()
plt.title('ROC AUC vs Epoch by Species')
plt.xlabel('Epoch')
plt.ylabel('ROC AUC')
plt.show()

# avg roc aucs
roc_aucs = np.mean(roc_aucs_by_epoch, axis=1)
plt.plot(np.arange(1,101), roc_aucs)
plt.title('Averge ROC AUC vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('ROC AUC')
plt.show()

# %% [markdown]
# Average RelRMSE drops until about epoch 30 and then flatlines. Average ROC AUC increases quickly until about epoch 20 and then slowly increases until around epoch 80. So again, we chose 80 for the number of epochs to train our champion model.

# %% [markdown]
# ### Part f
#
# Use your champion model to evaluate on the test set. Report AUC for each animal species for the classification task. Report the relative root mean squared error for the counting task.

# %% [markdown]
# **Training & Testing Champion Model**

# %%
# Create dataloader
nontest_dataset = ClassifyCountDataset(dataset_type = 'trainval', img_size = 128)
test_dataset = ClassifyCountDataset(dataset_type = 'test', img_size = 128)

nontest_dataloader = DataLoader(nontest_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
torch.manual_seed(2023)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# train full model
champ_epoch = 80
bestmodel = VGG16Counting(num_classes=6).to(device)
optimizer = optim.Adam(bestmodel.parameters(), lr=1e-4)
roc_aucs_by_epoch, mses_by_epoch = train(bestmodel, optimizer,
                                         nontest_dataloader,
                                         test_dataloader,
                                         num_epochs=champ_epoch)
roc_aucs_by_epoch = np.array(roc_aucs_by_epoch)
mses_by_epoch = np.array(mses_by_epoch)
np.save('drive/My Drive/Iteration 3 Full/roc_aucs.npy', roc_aucs_by_epoch)
np.save('drive/My Drive/Iteration 3 Full/mses.npy', mses_by_epoch)
# Out:
# ======================================================================
# Epoch: 1
# ======================================================================
# Average precision by class: [0.85, 0.755, 0.959, 0.711, 0.656, 0.931]
# Mean Relative Root Mean Squared Error: 0.5373
# ======================================================================
# Epoch: 2
# ======================================================================
# Average precision by class: [0.747, 0.705, 0.994, 0.931, 0.697, 0.97]
# Mean Relative Root Mean Squared Error: 0.4802
# ======================================================================
# Epoch: 3
# ======================================================================
# Average precision by class: [0.759, 0.812, 0.984, 0.732, 0.782, 0.961]
# Mean Relative Root Mean Squared Error: 0.4902
# ======================================================================
# Epoch: 4
# ======================================================================
# Average precision by class: [0.677, 0.899, 0.969, 0.834, 0.889, 0.929]
# Mean Relative Root Mean Squared Error: 0.4847
# ======================================================================
# Epoch: 5
# ======================================================================
# Average precision by class: [0.926, 0.875, 0.989, 0.845, 0.599, 0.96]
# Mean Relative Root Mean Squared Error: 0.4725
# ======================================================================
# Epoch: 6
# ======================================================================
# Average precision by class: [0.852, 0.802, 0.99, 0.75, 0.793, 0.975]
# Mean Relative Root Mean Squared Error: 0.4692
# ======================================================================
# Epoch: 7
# ======================================================================
# Average precision by class: [0.84, 0.897, 0.99, 0.864, 0.778, 0.974]
# Mean Relative Root Mean Squared Error: 0.4725
# ======================================================================
# Epoch: 8
# ======================================================================
# Average precision by class: [0.887, 0.728, 0.99, 0.864, 0.788, 0.964]
# Mean Relative Root Mean Squared Error: 0.4354
# ======================================================================
# Epoch: 9
# ======================================================================
# Average precision by class: [0.861, 0.866, 0.99, 0.85, 0.853, 0.99]
# Mean Relative Root Mean Squared Error: 0.4483
# ======================================================================
# Epoch: 10
# ======================================================================
# Average precision by class: [0.883, 0.759, 0.985, 0.817, 0.87, 0.971]
# Mean Relative Root Mean Squared Error: 0.4512
# ======================================================================
# Epoch: 11
# ======================================================================
# Average precision by class: [0.887, 0.774, 0.985, 0.848, 0.818, 0.985]
# Mean Relative Root Mean Squared Error: 0.445
# ======================================================================
# Epoch: 12
# ======================================================================
# Average precision by class: [0.92, 0.657, 0.99, 0.989, 0.758, 0.985]
# Mean Relative Root Mean Squared Error: 0.4341
# ======================================================================
# Epoch: 13
# ======================================================================
# Average precision by class: [0.85, 0.764, 0.985, 0.909, 0.911, 0.985]
# Mean Relative Root Mean Squared Error: 0.428
# ======================================================================
# Epoch: 14
# ======================================================================
# Average precision by class: [0.922, 0.839, 0.995, 0.801, 0.878, 0.975]
# Mean Relative Root Mean Squared Error: 0.4115
# ======================================================================
# Epoch: 15
# ======================================================================
# Average precision by class: [0.851, 0.962, 0.99, 0.832, 0.894, 0.966]
# Mean Relative Root Mean Squared Error: 0.4059
# ======================================================================
# Epoch: 16
# ======================================================================
# Average precision by class: [0.973, 0.863, 0.985, 0.833, 0.863, 0.948]
# Mean Relative Root Mean Squared Error: 0.4406
# ======================================================================
# Epoch: 17
# ======================================================================
# Average precision by class: [0.87, 0.94, 0.985, 0.808, 0.923, 0.995]
# Mean Relative Root Mean Squared Error: 0.3979
# ======================================================================
# Epoch: 18
# ======================================================================
# Average precision by class: [0.784, 0.943, 0.98, 0.845, 0.897, 0.995]
# Mean Relative Root Mean Squared Error: 0.4318
# ======================================================================
# Epoch: 19
# ======================================================================
# Average precision by class: [0.929, 0.944, 0.98, 0.856, 0.856, 0.99]
# Mean Relative Root Mean Squared Error: 0.4064
# ======================================================================
# Epoch: 20
# ======================================================================
# Average precision by class: [0.974, 0.919, 0.985, 0.826, 0.808, 0.961]
# Mean Relative Root Mean Squared Error: 0.3796
# ======================================================================
# Epoch: 21
# ======================================================================
# Average precision by class: [0.802, 0.958, 0.985, 0.836, 0.916, 0.985]
# Mean Relative Root Mean Squared Error: 0.4109
# ======================================================================
# Epoch: 22
# ======================================================================
# Average precision by class: [0.938, 0.925, 0.995, 0.687, 0.849, 0.99]
# Mean Relative Root Mean Squared Error: 0.3931
# ======================================================================
# Epoch: 23
# ======================================================================
# Average precision by class: [0.923, 0.926, 0.961, 0.856, 0.863, 0.966]
# Mean Relative Root Mean Squared Error: 0.3943
# ======================================================================
# Epoch: 24
# ======================================================================
# Average precision by class: [0.964, 0.927, 0.99, 0.87, 0.843, 0.985]
# Mean Relative Root Mean Squared Error: 0.3907
# ======================================================================
# Epoch: 25
# ======================================================================
# Average precision by class: [0.853, 0.876, 0.985, 0.845, 0.936, 0.995]
# Mean Relative Root Mean Squared Error: 0.4238
# ======================================================================
# Epoch: 26
# ======================================================================
# Average precision by class: [0.943, 0.852, 0.985, 0.893, 0.826, 0.995]
# Mean Relative Root Mean Squared Error: 0.4053
# ======================================================================
# Epoch: 27
# ======================================================================
# Average precision by class: [0.942, 0.97, 0.98, 0.813, 0.793, 0.99]
# Mean Relative Root Mean Squared Error: 0.4041
# ======================================================================
# Epoch: 28
# ======================================================================
# Average precision by class: [0.944, 0.988, 0.99, 0.851, 0.845, 0.99]
# Mean Relative Root Mean Squared Error: 0.3867
# ======================================================================
# Epoch: 29
# ======================================================================
# Average precision by class: [0.89, 0.929, 0.99, 0.856, 0.794, 0.995]
# Mean Relative Root Mean Squared Error: 0.4033
# ======================================================================
# Epoch: 30
# ======================================================================
# Average precision by class: [0.862, 0.888, 0.99, 0.869, 0.942, 0.995]
# Mean Relative Root Mean Squared Error: 0.3973
# ======================================================================
# Epoch: 31
# ======================================================================
# Average precision by class: [0.917, 0.884, 0.995, 0.868, 0.91, 0.961]
# Mean Relative Root Mean Squared Error: 0.4097
# ======================================================================
# Epoch: 32
# ======================================================================
# Average precision by class: [0.98, 0.865, 0.985, 0.9, 0.791, 0.99]
# Mean Relative Root Mean Squared Error: 0.4135
# ======================================================================
# Epoch: 33
# ======================================================================
# Average precision by class: [0.852, 0.88, 0.985, 0.922, 0.929, 0.98]
# Mean Relative Root Mean Squared Error: 0.3983
# ======================================================================
# Epoch: 34
# ======================================================================
# Average precision by class: [0.943, 0.944, 0.995, 0.878, 0.816, 0.985]
# Mean Relative Root Mean Squared Error: 0.4206
# ======================================================================
# Epoch: 35
# ======================================================================
# Average precision by class: [0.896, 0.966, 0.99, 0.872, 0.858, 0.975]
# Mean Relative Root Mean Squared Error: 0.4007
# ======================================================================
# Epoch: 36
# ======================================================================
# Average precision by class: [0.934, 0.899, 1.0, 0.725, 0.922, 0.966]
# Mean Relative Root Mean Squared Error: 0.3895
# ======================================================================
# Epoch: 37
# ======================================================================
# Average precision by class: [0.894, 0.889, 0.98, 0.853, 0.902, 0.99]
# Mean Relative Root Mean Squared Error: 0.4142
# ======================================================================
# Epoch: 38
# ======================================================================
# Average precision by class: [0.889, 0.924, 0.99, 0.858, 0.916, 0.98]
# Mean Relative Root Mean Squared Error: 0.4039
# ======================================================================
# Epoch: 39
# ======================================================================
# Average precision by class: [0.887, 0.934, 0.995, 0.821, 0.876, 0.985]
# Mean Relative Root Mean Squared Error: 0.4101
# ======================================================================
# Epoch: 40
# ======================================================================
# Average precision by class: [0.95, 0.944, 0.99, 0.9, 0.736, 0.99]
# Mean Relative Root Mean Squared Error: 0.3854
# ======================================================================
# Epoch: 41
# ======================================================================
# Average precision by class: [0.856, 0.876, 0.99, 0.874, 0.926, 0.99]
# Mean Relative Root Mean Squared Error: 0.3984
# ======================================================================
# Epoch: 42
# ======================================================================
# Average precision by class: [0.952, 0.955, 0.995, 0.867, 0.774, 0.985]
# Mean Relative Root Mean Squared Error: 0.4033
# ======================================================================
# Epoch: 43
# ======================================================================
# Average precision by class: [0.881, 0.941, 0.98, 0.863, 0.899, 0.99]
# Mean Relative Root Mean Squared Error: 0.3872
# ======================================================================
# Epoch: 44
# ======================================================================
# Average precision by class: [0.893, 0.921, 0.995, 0.839, 0.898, 0.99]
# Mean Relative Root Mean Squared Error: 0.4165
# ======================================================================
# Epoch: 45
# ======================================================================
# Average precision by class: [0.878, 0.93, 0.995, 0.864, 0.916, 0.995]
# Mean Relative Root Mean Squared Error: 0.3862
# ======================================================================
# Epoch: 46
# ======================================================================
# Average precision by class: [0.929, 0.955, 0.99, 0.871, 0.829, 0.985]
# Mean Relative Root Mean Squared Error: 0.3888
# ======================================================================
# Epoch: 47
# ======================================================================
# Average precision by class: [0.922, 0.981, 0.975, 0.803, 0.828, 0.995]
# Mean Relative Root Mean Squared Error: 0.4
# ======================================================================
# Epoch: 48
# ======================================================================
# Average precision by class: [0.944, 0.929, 0.99, 0.894, 0.808, 0.995]
# Mean Relative Root Mean Squared Error: 0.4094
# ======================================================================
# Epoch: 49
# ======================================================================
# Average precision by class: [0.935, 0.893, 0.985, 0.868, 0.848, 0.971]
# Mean Relative Root Mean Squared Error: 0.3848
# ======================================================================
# Epoch: 50
# ======================================================================
# Average precision by class: [0.952, 0.907, 0.995, 0.9, 0.767, 0.98]
# Mean Relative Root Mean Squared Error: 0.3921
# ======================================================================
# Epoch: 51
# ======================================================================
# Average precision by class: [0.926, 0.84, 0.995, 0.875, 0.882, 0.995]
# Mean Relative Root Mean Squared Error: 0.3911
# ======================================================================
# Epoch: 52
# ======================================================================
# Average precision by class: [0.873, 0.971, 0.975, 0.88, 0.888, 0.995]
# Mean Relative Root Mean Squared Error: 0.4061
# ======================================================================
# Epoch: 53
# ======================================================================
# Average precision by class: [0.904, 0.88, 0.985, 0.902, 0.887, 0.995]
# Mean Relative Root Mean Squared Error: 0.4042
# ======================================================================
# Epoch: 54
# ======================================================================
# Average precision by class: [0.886, 0.923, 0.975, 0.87, 0.912, 0.975]
# Mean Relative Root Mean Squared Error: 0.4004
# ======================================================================
# Epoch: 55
# ======================================================================
# Average precision by class: [0.919, 0.871, 0.985, 0.858, 0.873, 0.985]
# Mean Relative Root Mean Squared Error: 0.4036
# ======================================================================
# Epoch: 56
# ======================================================================
# Average precision by class: [0.853, 0.94, 0.98, 0.814, 0.931, 0.99]
# Mean Relative Root Mean Squared Error: 0.3865
# ======================================================================
# Epoch: 57
# ======================================================================
# Average precision by class: [0.889, 0.905, 0.99, 0.856, 0.975, 0.985]
# Mean Relative Root Mean Squared Error: 0.4056
# ======================================================================
# Epoch: 58
# ======================================================================
# Average precision by class: [0.912, 0.896, 0.98, 0.937, 0.894, 0.985]
# Mean Relative Root Mean Squared Error: 0.4045
# ======================================================================
# Epoch: 59
# ======================================================================
# Average precision by class: [0.896, 0.927, 0.98, 0.874, 0.935, 0.985]
# Mean Relative Root Mean Squared Error: 0.3993
# ======================================================================
# Epoch: 60
# ======================================================================
# Average precision by class: [0.916, 0.947, 0.975, 0.872, 0.885, 0.98]
# Mean Relative Root Mean Squared Error: 0.3835
# ======================================================================
# Epoch: 61
# ======================================================================
# Average precision by class: [0.951, 0.937, 0.985, 0.831, 0.85, 0.971]
# Mean Relative Root Mean Squared Error: 0.3871
# ======================================================================
# Epoch: 62
# ======================================================================
# Average precision by class: [0.92, 0.89, 0.99, 0.868, 0.894, 0.98]
# Mean Relative Root Mean Squared Error: 0.4201
# ======================================================================
# Epoch: 63
# ======================================================================
# Average precision by class: [0.884, 0.933, 0.985, 0.854, 0.917, 0.99]
# Mean Relative Root Mean Squared Error: 0.4182
# ======================================================================
# Epoch: 64
# ======================================================================
# Average precision by class: [0.863, 0.956, 0.995, 0.86, 0.919, 0.995]
# Mean Relative Root Mean Squared Error: 0.3985
# ======================================================================
# Epoch: 65
# ======================================================================
# Average precision by class: [0.918, 0.983, 0.985, 0.867, 0.884, 0.99]
# Mean Relative Root Mean Squared Error: 0.3947
# ======================================================================
# Epoch: 66
# ======================================================================
# Average precision by class: [0.963, 0.912, 0.99, 0.873, 0.797, 0.966]
# Mean Relative Root Mean Squared Error: 0.4037
# ======================================================================
# Epoch: 67
# ======================================================================
# Average precision by class: [0.959, 0.946, 0.99, 0.893, 0.859, 0.99]
# Mean Relative Root Mean Squared Error: 0.4104
# ======================================================================
# Epoch: 68
# ======================================================================
# Average precision by class: [0.904, 0.95, 0.995, 0.881, 0.865, 0.98]
# Mean Relative Root Mean Squared Error: 0.4179
# ======================================================================
# Epoch: 69
# ======================================================================
# Average precision by class: [0.94, 0.94, 0.995, 0.857, 0.909, 0.98]
# Mean Relative Root Mean Squared Error: 0.3822
# ======================================================================
# Epoch: 70
# ======================================================================
# Average precision by class: [0.843, 0.836, 0.98, 0.895, 0.926, 0.98]
# Mean Relative Root Mean Squared Error: 0.4095
# ======================================================================
# Epoch: 71
# ======================================================================
# Average precision by class: [0.918, 0.931, 0.99, 0.877, 0.916, 0.975]
# Mean Relative Root Mean Squared Error: 0.387
# ======================================================================
# Epoch: 72
# ======================================================================
# Average precision by class: [0.953, 0.891, 0.971, 0.87, 0.832, 1.0]
# Mean Relative Root Mean Squared Error: 0.4125
# ======================================================================
# Epoch: 73
# ======================================================================
# Average precision by class: [0.908, 0.956, 0.985, 0.88, 0.914, 0.975]
# Mean Relative Root Mean Squared Error: 0.3931
# ======================================================================
# Epoch: 74
# ======================================================================
# Average precision by class: [0.944, 0.904, 0.99, 0.848, 0.828, 0.985]
# Mean Relative Root Mean Squared Error: 0.4246
# ======================================================================
# Epoch: 75
# ======================================================================
# Average precision by class: [0.947, 0.922, 0.985, 0.888, 0.793, 0.99]
# Mean Relative Root Mean Squared Error: 0.3908
# ======================================================================
# Epoch: 76
# ======================================================================
# Average precision by class: [0.898, 0.895, 0.995, 0.852, 0.92, 0.99]
# Mean Relative Root Mean Squared Error: 0.4025
# ======================================================================
# Epoch: 77
# ======================================================================
# Average precision by class: [0.863, 0.913, 0.995, 0.911, 0.898, 0.995]
# Mean Relative Root Mean Squared Error: 0.4011
# ======================================================================
# Epoch: 78
# ======================================================================
# Average precision by class: [0.948, 0.908, 0.985, 0.868, 0.848, 0.985]
# Mean Relative Root Mean Squared Error: 0.3656
# ======================================================================
# Epoch: 79
# ======================================================================
# Average precision by class: [0.964, 0.914, 0.98, 0.87, 0.842, 0.966]
# Mean Relative Root Mean Squared Error: 0.3942
# ======================================================================
# Epoch: 80
# ======================================================================
# Average precision by class: [0.912, 0.921, 0.99, 0.907, 0.803, 0.995]
# Mean Relative Root Mean Squared Error: 0.3991

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bestmodel = VGG16Counting(num_classes=6).to(device)
champ_epoch = 80
PATH = f'drive/My Drive/Iteration 3 Full/epoch_{champ_epoch}.pth'
bestmodel.load_state_dict(torch.load(PATH))
bestmodel.eval()

roc_aucs_on_test, relrmses_on_test = eval_batch_loop(bestmodel,
                                                     test_dataloader,
                                                     device)
# Out:
# Average precision by class: [0.912, 0.921, 0.99, 0.907, 0.803, 0.995]
# Mean Relative Root Mean Squared Error: 0.3599

# %%
# Displaying Test Scores
avg_relrmse = np.mean(relrmses_on_test)
avg_roc_auc = np.mean(roc_aucs_on_test)

final_relrmses = np.append(relrmses_on_test, avg_relrmse)
final_roc_aucs = np.append(roc_aucs_on_test, avg_roc_auc)

labels = reduced_classes.copy()
labels.append('average')
for i in range(7):
  lbl = labels[i]
  relrmse_i = str(round(final_relrmses[i], 2))
  roc_auc_i = str(round(final_roc_aucs[i], 2))
  string = 'RelRMSE = ' + relrmse_i + '  & ROC AUC = ' + roc_auc_i + '  : ' + lbl
  print(string)
# Out:
# RelRMSE = 0.26  & ROC AUC = 0.93  : giraffe_reticulated
# RelRMSE = 0.49  & ROC AUC = 0.96  : zebra_grevys
# RelRMSE = 0.06  & ROC AUC = 0.99  : turtle_sea
# RelRMSE = 0.84  & ROC AUC = 0.88  : zebra_plains
# RelRMSE = 0.45  & ROC AUC = 0.92  : giraffe_masai
# RelRMSE = 0.06  & ROC AUC = 1.0  : whale_fluke
# RelRMSE = 0.36  & ROC AUC = 0.95  : average
