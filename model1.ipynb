# %% [markdown]
# <a href="https://colab.research.google.com/github/TylerFeemster/SafariNet/blob/main/model1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
_ = !unzip 'drive/MyDrive/wild.zip'
print('Complete')
# Out:
# Mounted at /content/drive
# Complete

# %%
import sys
sys.path.append('drive/MyDrive/SafariNet')

# %% [markdown]
# # Iteration 1

# %% [markdown]
# ## Model Architecture
#
# In this section we will define a convolutional neural network (CNN) that predicts the animals shown on a image, as well as the counts for each animal.  Because our CNN is supposed to produce two different kinds of outputs (animal class identifications and animal counts for each class) our CNN needs to be structured accordingly.
#
#
# Skim through the Introduction section and read section 3.1 of the paper [*Learn to Classify and Count: A Unified Framework for Object Classification and Counting*](https://dl.acm.org/doi/abs/10.1145/3191442.3191459) by Song and Qui.  This should give you a better idea of the structure of the network that we are going to build since our CNN will have an architecture similar to the network in the paper but simpler.  Following similar steps as the ones in the paper, we will build a CNN that has 2 output branches.  Just as the method described in the paper, we will train the upstream layers jointly.  However, instead of using the famous [VGG-16](https://builtin.com/machine-learning/vgg16) network architecture for the upstream layers, we will only borrow the architecture of the first few layers of VGG-16.  This is because VGG-16 has approximately 138 millions of hyperparameters and it will take a long time to train the entire VGG-16.
#
# The code in the next cell provides you the partial code for building the network for this project.  Please fill in the parts labeled with `...`.  There might be more than one entry needed for each `...`.  You can assume that the input images are of size 128 x 128.
#
# [Batch normalization](https://datahacker.rs/017-pytorch-how-to-apply-batch-normalization-in-pytorch/) is a popular technique used for improving deep neural network performance.  We will use the [torch.nn.BatchNorm2d() function](https://pytorch.org/docs/stable/generated/torch.nn.BatchNorm2d.html) to do batch normalization and keep the default values for its input arguments.  Note that batch normalization does not change the shape of its input or output.
#
# Just a reminder: The `nn.Sequential()` function was discussed in Chapter 8.5 of the lecture notes.
#
# I have described the architecture of the network below:
#
# For **block 1**:
#
# * first layer:
#     + a convolutional layer with 64 channels with (5 x 5) filters (kernels) with no padding; batch normalization; activation function: relu.
#
# * second layer:
#     + a convolutional layer with 64 channels with (5 x 5) filters; batch normalization; activation function: relu.
#     + a maximum pooling layer with (2 x 2 filter), each time move the filter 2 steps when moving horizontally and vertically, no padding
#
#
# For **block 2**:
#
# * first layer:
#     + a convolutional layer with 128 channels with (5 x 5) filters with no padding; batch normalization; activation function: relu.
#
# * second layer:
#     + a convolutional layer with 128 channels with (5 x 5) filters with no padding; batch normalization; activation function: relu.
#     + a maximum pooling layer with (2 x 2 filter), each time move the filter 2 steps when moving horizontally and vertically, no padding
#
#
# For each of the **branches**
#
# The following two layers are coded with the *self.branches.append()* function
#
# * first layer:
#     + a convolutional layer with 128 channels with (3 x 3) filters with one row/column of zeros added to all four sides of the input; batch normalization; activation function: relu.
#
# * second layer:
#     + a convolutional layer with 128 channels with (3 x 3) filters with one row/column of zeros added to all four sides of the input; batch normalization; activation function: relu.
#     + a maximum pooling layer with (2 x 2 filter), each time move the filter 2 steps when moving horizontally and vertically, no padding
#
# Third layer: flatten
#
# The following layers are coded with the *self.outputs.append()* function
#
#
# * fourth layer:
#     + dense layer with 256 neurons; activation function: relu
#     + dropout rate: 50%
#
#
# * output layer.

# %%
from model import VGG16Counting
from utils import train

# %% [markdown]
# Note that the loss function is defined to be the sum of two loss functions: `MSELoss()` and `BCEWithLogitsLoss()`.  This is inspired by the loss function used in the paper by Song and Qui. These are natural choices for (1) the regression task and (2) the classification task. The use of `BCEWithLogitsLoss()` (instead of `nn.CrossEntropyLoss()`) means that we use the sigmoid function (instead of the softmax function) as the activation function for the last layer of the classification branch. This is better suited to our dataset since there are many images with more than one type of animal present. Softmax would force the class probabilities to sum to 1, but our dataset does not have mutually exclusive labels.

# %% [markdown]
# ## Initial Training

# %%
# Dataloaders
from dataset import ClassifyCountDataset
from torch.utils.data import DataLoader

train_dataset = ClassifyCountDataset(dataset_type = 'train', img_size = 128)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

val_dataset = ClassifyCountDataset(dataset_type = 'val', img_size = 128)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
import torch
import numpy as np
import os

torch.manual_seed(2023)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model1 = VGG16Counting(num_classes=6).to(device)
save_path = 'drive/MyDrive/SafariNet/Iteration1'
os.makedirs(save_path, exist_ok = True)

# %%
roc_aucs_by_epoch, mses_by_epoch = train(model1,
                                         train_dataloader,
                                         val_dataloader,
                                         save_path=save_path)
np.save(save_path + '/aurocs.npy', roc_aucs_by_epoch)
np.save(save_path + '/mses.npy', mses_by_epoch)
# Out:
# ======================================================================
# Epoch: 1
# ======================================================================
# Average precision by class: [0.829, 0.644, 0.988, 0.832, 0.746, 0.935]
# Mean Relative Root Mean Squared Error: 0.6061
# ======================================================================
# Epoch: 2
# ======================================================================
# Average precision by class: [0.792, 0.629, 0.989, 0.89, 0.683, 0.82]
# Mean Relative Root Mean Squared Error: 0.5894
# ======================================================================
# Epoch: 3
# ======================================================================
# Average precision by class: [0.848, 0.779, 0.983, 0.946, 0.642, 0.882]
# Mean Relative Root Mean Squared Error: 0.6081
# ======================================================================
# Epoch: 4
# ======================================================================
# Average precision by class: [0.823, 0.859, 0.989, 0.87, 0.728, 0.86]
# Mean Relative Root Mean Squared Error: 0.5444
# ======================================================================
# Epoch: 5
# ======================================================================
# Average precision by class: [0.914, 0.822, 0.968, 0.99, 0.535, 0.984]
# Mean Relative Root Mean Squared Error: 0.5312
# ======================================================================
# Epoch: 6
# ======================================================================
# Average precision by class: [0.977, 0.838, 0.949, 0.501, 0.795, 0.913]
# Mean Relative Root Mean Squared Error: 0.522
# ======================================================================
# Epoch: 7
# ======================================================================
# Average precision by class: [0.886, 0.773, 0.989, 0.934, 0.594, 1.0]
# Mean Relative Root Mean Squared Error: 0.4927
# ======================================================================
# Epoch: 8
# ======================================================================
# Average precision by class: [0.758, 0.942, 0.954, 0.882, 0.872, 0.995]
# Mean Relative Root Mean Squared Error: 0.4513
# ======================================================================
# Epoch: 9
# ======================================================================
# Average precision by class: [0.982, 0.788, 0.964, 0.766, 0.798, 0.955]
# Mean Relative Root Mean Squared Error: 0.5079
# ======================================================================
# Epoch: 10
# ======================================================================
# Average precision by class: [0.982, 0.755, 0.96, 1.0, 0.635, 0.95]
# Mean Relative Root Mean Squared Error: 0.4616
# ======================================================================
# Epoch: 11
# ======================================================================
# Average precision by class: [0.8, 0.891, 0.969, 0.688, 0.858, 0.984]
# Mean Relative Root Mean Squared Error: 0.4617
# ======================================================================
# Epoch: 12
# ======================================================================
# Average precision by class: [0.789, 0.916, 0.956, 0.953, 0.792, 0.984]
# Mean Relative Root Mean Squared Error: 0.4748
# ======================================================================
# Epoch: 13
# ======================================================================
# Average precision by class: [0.889, 0.851, 0.989, 0.931, 0.827, 0.946]
# Mean Relative Root Mean Squared Error: 0.4516
# ======================================================================
# Epoch: 14
# ======================================================================
# Average precision by class: [0.779, 0.782, 0.969, 0.95, 0.958, 1.0]
# Mean Relative Root Mean Squared Error: 0.4394
# ======================================================================
# Epoch: 15
# ======================================================================
# Average precision by class: [0.939, 0.894, 0.969, 0.927, 0.788, 0.974]
# Mean Relative Root Mean Squared Error: 0.4571
# ======================================================================
# Epoch: 16
# ======================================================================
# Average precision by class: [0.829, 0.79, 0.99, 0.927, 0.872, 0.989]
# Mean Relative Root Mean Squared Error: 0.4527
# ======================================================================
# Epoch: 17
# ======================================================================
# Average precision by class: [0.666, 0.87, 0.938, 1.0, 0.897, 0.995]
# Mean Relative Root Mean Squared Error: 0.4719
# ======================================================================
# Epoch: 18
# ======================================================================
# Average precision by class: [0.879, 0.81, 0.989, 0.952, 0.894, 0.995]
# Mean Relative Root Mean Squared Error: 0.42
# ======================================================================
# Epoch: 19
# ======================================================================
# Average precision by class: [0.823, 0.958, 0.984, 0.905, 0.861, 0.955]
# Mean Relative Root Mean Squared Error: 0.4326
# ======================================================================
# Epoch: 20
# ======================================================================
# Average precision by class: [0.905, 0.911, 0.99, 0.951, 0.846, 0.995]
# Mean Relative Root Mean Squared Error: 0.4076
# ======================================================================
# Epoch: 21
# ======================================================================
# Average precision by class: [0.943, 0.914, 0.99, 0.805, 0.793, 0.95]
# Mean Relative Root Mean Squared Error: 0.3807
# ======================================================================
# Epoch: 22
# ======================================================================
# Average precision by class: [0.903, 0.882, 0.99, 0.927, 0.862, 0.989]
# Mean Relative Root Mean Squared Error: 0.4291
# ======================================================================
# Epoch: 23
# ======================================================================
# Average precision by class: [0.836, 0.909, 0.969, 0.856, 0.942, 0.931]
# Mean Relative Root Mean Squared Error: 0.4049
# ======================================================================
# Epoch: 24
# ======================================================================
# Average precision by class: [0.95, 0.844, 0.99, 0.93, 0.764, 0.959]
# Mean Relative Root Mean Squared Error: 0.4144
# ======================================================================
# Epoch: 25
# ======================================================================
# Average precision by class: [0.814, 0.898, 0.979, 0.869, 0.944, 1.0]
# Mean Relative Root Mean Squared Error: 0.4271
# ======================================================================
# Epoch: 26
# ======================================================================
# Average precision by class: [0.887, 0.979, 0.995, 0.788, 0.917, 1.0]
# Mean Relative Root Mean Squared Error: 0.4293
# ======================================================================
# Epoch: 27
# ======================================================================
# Average precision by class: [0.801, 0.876, 0.985, 0.889, 0.989, 0.995]
# Mean Relative Root Mean Squared Error: 0.4395
# ======================================================================
# Epoch: 28
# ======================================================================
# Average precision by class: [0.916, 0.866, 0.989, 0.862, 0.878, 0.984]
# Mean Relative Root Mean Squared Error: 0.4364
# ======================================================================
# Epoch: 29
# ======================================================================
# Average precision by class: [0.768, 0.934, 0.979, 0.954, 0.877, 0.994]
# Mean Relative Root Mean Squared Error: 0.4141
# ======================================================================
# Epoch: 30
# ======================================================================
# Average precision by class: [0.865, 0.897, 0.995, 0.938, 0.891, 0.99]
# Mean Relative Root Mean Squared Error: 0.4104
# ======================================================================
# Epoch: 31
# ======================================================================
# Average precision by class: [0.914, 0.832, 0.98, 0.834, 0.907, 0.969]
# Mean Relative Root Mean Squared Error: 0.4121
# ======================================================================
# Epoch: 32
# ======================================================================
# Average precision by class: [0.89, 0.867, 0.995, 0.922, 0.886, 0.989]
# Mean Relative Root Mean Squared Error: 0.3986
# ======================================================================
# Epoch: 33
# ======================================================================
# Average precision by class: [0.899, 0.867, 0.99, 0.932, 0.828, 1.0]
# Mean Relative Root Mean Squared Error: 0.4391
# ======================================================================
# Epoch: 34
# ======================================================================
# Average precision by class: [0.886, 0.912, 0.995, 0.936, 0.849, 0.995]
# Mean Relative Root Mean Squared Error: 0.4228
# ======================================================================
# Epoch: 35
# ======================================================================
# Average precision by class: [0.932, 0.878, 1.0, 0.934, 0.828, 0.964]
# Mean Relative Root Mean Squared Error: 0.3953
# ======================================================================
# Epoch: 36
# ======================================================================
# Average precision by class: [0.841, 0.899, 0.995, 0.947, 0.915, 1.0]
# Mean Relative Root Mean Squared Error: 0.4347
# ======================================================================
# Epoch: 37
# ======================================================================
# Average precision by class: [0.968, 0.849, 0.995, 0.888, 0.831, 0.984]
# Mean Relative Root Mean Squared Error: 0.4
# ======================================================================
# Epoch: 38
# ======================================================================
# Average precision by class: [0.879, 0.85, 0.984, 0.987, 0.885, 0.989]
# Mean Relative Root Mean Squared Error: 0.4392
# ======================================================================
# Epoch: 39
# ======================================================================
# Average precision by class: [0.864, 0.904, 1.0, 0.879, 0.91, 1.0]
# Mean Relative Root Mean Squared Error: 0.4252
# ======================================================================
# Epoch: 40
# ======================================================================
# Average precision by class: [0.914, 0.836, 0.994, 0.907, 0.81, 1.0]
# Mean Relative Root Mean Squared Error: 0.4271
# ======================================================================
# Epoch: 41
# ======================================================================
# Average precision by class: [0.882, 0.865, 0.98, 0.885, 0.869, 0.989]
# Mean Relative Root Mean Squared Error: 0.4117
# ======================================================================
# Epoch: 42
# ======================================================================
# Average precision by class: [0.863, 0.94, 0.995, 0.931, 0.784, 1.0]
# Mean Relative Root Mean Squared Error: 0.4345
# ======================================================================
# Epoch: 43
# ======================================================================
# Average precision by class: [0.904, 0.877, 0.985, 0.958, 0.853, 0.974]
# Mean Relative Root Mean Squared Error: 0.4267
# ======================================================================
# Epoch: 44
# ======================================================================
# Average precision by class: [0.923, 0.925, 0.99, 0.699, 0.949, 0.979]
# Mean Relative Root Mean Squared Error: 0.4259
# ======================================================================
# Epoch: 45
# ======================================================================
# Average precision by class: [0.844, 0.878, 1.0, 0.903, 0.789, 0.979]
# Mean Relative Root Mean Squared Error: 0.475
# ======================================================================
# Epoch: 46
# ======================================================================
# Average precision by class: [0.904, 0.901, 0.995, 0.976, 0.935, 0.995]
# Mean Relative Root Mean Squared Error: 0.4134
# ======================================================================
# Epoch: 47
# ======================================================================
# Average precision by class: [0.915, 0.921, 0.99, 0.953, 0.864, 0.979]
# Mean Relative Root Mean Squared Error: 0.4196
# ======================================================================
# Epoch: 48
# ======================================================================
# Average precision by class: [0.961, 0.93, 0.979, 0.882, 0.818, 0.969]
# Mean Relative Root Mean Squared Error: 0.425
# ======================================================================
# Epoch: 49
# ======================================================================
# Average precision by class: [0.975, 0.865, 0.974, 0.97, 0.82, 0.974]
# Mean Relative Root Mean Squared Error: 0.4637
# ======================================================================
# Epoch: 50
# ======================================================================
# Average precision by class: [0.957, 0.925, 0.975, 0.899, 0.78, 0.944]
# Mean Relative Root Mean Squared Error: 0.4133
# ======================================================================
# Epoch: 51
# ======================================================================
# Average precision by class: [0.897, 0.926, 0.985, 0.854, 0.938, 0.989]
# Mean Relative Root Mean Squared Error: 0.4072
# ======================================================================
# Epoch: 52
# ======================================================================
# Average precision by class: [0.94, 0.907, 0.98, 0.86, 0.89, 0.969]
# Mean Relative Root Mean Squared Error: 0.4231
# ======================================================================
# Epoch: 53
# ======================================================================
# Average precision by class: [0.905, 0.883, 0.989, 0.976, 0.787, 0.969]
# Mean Relative Root Mean Squared Error: 0.4283
# ======================================================================
# Epoch: 54
# ======================================================================
# Average precision by class: [0.914, 0.877, 0.99, 0.978, 0.807, 0.989]
# Mean Relative Root Mean Squared Error: 0.4223
# ======================================================================
# Epoch: 55
# ======================================================================
# Average precision by class: [0.872, 0.903, 0.995, 0.971, 0.91, 0.984]
# Mean Relative Root Mean Squared Error: 0.4461
# ======================================================================
# Epoch: 56
# ======================================================================
# Average precision by class: [0.819, 0.87, 1.0, 0.968, 0.955, 0.979]
# Mean Relative Root Mean Squared Error: 0.4193
# ======================================================================
# Epoch: 57
# ======================================================================
# Average precision by class: [0.917, 0.862, 0.985, 0.916, 0.864, 1.0]
# Mean Relative Root Mean Squared Error: 0.4409
# ======================================================================
# Epoch: 58
# ======================================================================
# Average precision by class: [0.845, 0.855, 0.995, 0.875, 0.966, 0.94]
# Mean Relative Root Mean Squared Error: 0.4186
# ======================================================================
# Epoch: 59
# ======================================================================
# Average precision by class: [0.795, 0.939, 0.985, 0.86, 0.948, 1.0]
# Mean Relative Root Mean Squared Error: 0.4069
# ======================================================================
# Epoch: 60
# ======================================================================
# Average precision by class: [0.91, 0.886, 0.995, 0.976, 0.89, 0.979]
# Mean Relative Root Mean Squared Error: 0.4267
# ======================================================================
# Epoch: 61
# ======================================================================
# Average precision by class: [0.892, 0.806, 0.985, 0.96, 0.94, 1.0]
# Mean Relative Root Mean Squared Error: 0.4337
# ======================================================================
# Epoch: 62
# ======================================================================
# Average precision by class: [0.957, 0.934, 0.99, 0.85, 0.773, 0.913]
# Mean Relative Root Mean Squared Error: 0.4234
# ======================================================================
# Epoch: 63
# ======================================================================
# Average precision by class: [0.912, 0.912, 0.956, 0.934, 0.896, 0.989]
# Mean Relative Root Mean Squared Error: 0.4406
# ======================================================================
# Epoch: 64
# ======================================================================
# Average precision by class: [0.84, 0.871, 0.99, 0.945, 0.924, 1.0]
# Mean Relative Root Mean Squared Error: 0.4416
# ======================================================================
# Epoch: 65
# ======================================================================
# Average precision by class: [0.891, 0.811, 0.995, 0.903, 0.893, 1.0]
# Mean Relative Root Mean Squared Error: 0.4079
# ======================================================================
# Epoch: 66
# ======================================================================
# Average precision by class: [0.768, 0.865, 0.99, 0.953, 0.912, 1.0]
# Mean Relative Root Mean Squared Error: 0.4175
# ======================================================================
# Epoch: 67
# ======================================================================
# Average precision by class: [0.959, 0.886, 0.93, 0.784, 0.903, 0.935]
# Mean Relative Root Mean Squared Error: 0.4502
# ======================================================================
# Epoch: 68
# ======================================================================
# Average precision by class: [0.912, 0.918, 0.989, 0.882, 0.845, 0.974]
# Mean Relative Root Mean Squared Error: 0.4213
# ======================================================================
# Epoch: 69
# ======================================================================
# Average precision by class: [0.874, 0.843, 0.956, 0.97, 0.911, 0.969]
# Mean Relative Root Mean Squared Error: 0.4472
# ======================================================================
# Epoch: 70
# ======================================================================
# Average precision by class: [0.891, 0.883, 1.0, 0.983, 0.874, 0.95]
# Mean Relative Root Mean Squared Error: 0.4134
# ======================================================================
# Epoch: 71
# ======================================================================
# Average precision by class: [0.881, 0.921, 0.995, 0.889, 0.831, 0.95]
# Mean Relative Root Mean Squared Error: 0.4241
# ======================================================================
# Epoch: 72
# ======================================================================
# Average precision by class: [0.919, 0.929, 0.99, 0.9, 0.847, 0.974]
# Mean Relative Root Mean Squared Error: 0.3987
# ======================================================================
# Epoch: 73
# ======================================================================
# Average precision by class: [0.833, 0.87, 0.995, 0.948, 0.936, 0.969]
# Mean Relative Root Mean Squared Error: 0.4453
# ======================================================================
# Epoch: 74
# ======================================================================
# Average precision by class: [0.895, 0.889, 0.995, 0.916, 0.896, 0.984]
# Mean Relative Root Mean Squared Error: 0.4063
# ======================================================================
# Epoch: 75
# ======================================================================
# Average precision by class: [0.84, 0.896, 0.99, 0.957, 0.871, 0.984]
# Mean Relative Root Mean Squared Error: 0.4298
# ======================================================================
# Epoch: 76
# ======================================================================
# Average precision by class: [0.931, 0.887, 0.98, 0.903, 0.86, 0.995]
# Mean Relative Root Mean Squared Error: 0.4311
# ======================================================================
# Epoch: 77
# ======================================================================
# Average precision by class: [0.846, 0.827, 0.965, 0.941, 0.931, 0.984]
# Mean Relative Root Mean Squared Error: 0.4235
# ======================================================================
# Epoch: 78
# ======================================================================
# Average precision by class: [0.919, 0.771, 0.984, 0.966, 0.908, 0.974]
# Mean Relative Root Mean Squared Error: 0.4048
# ======================================================================
# Epoch: 79
# ======================================================================
# Average precision by class: [0.873, 0.915, 0.974, 0.888, 0.809, 0.955]
# Mean Relative Root Mean Squared Error: 0.4315
# ======================================================================
# Epoch: 80
# ======================================================================
# Average precision by class: [0.621, 0.928, 0.965, 0.966, 0.839, 0.984]
# Mean Relative Root Mean Squared Error: 0.4752
# ======================================================================
# Epoch: 81
# ======================================================================
# Average precision by class: [0.925, 0.716, 0.964, 0.961, 0.869, 1.0]
# Mean Relative Root Mean Squared Error: 0.4706
# ======================================================================
# Epoch: 82
# ======================================================================
# Average precision by class: [0.941, 0.951, 0.985, 0.938, 0.809, 0.979]
# Mean Relative Root Mean Squared Error: 0.4143
# ======================================================================
# Epoch: 83
# ======================================================================
# Average precision by class: [0.916, 0.936, 0.995, 0.93, 0.857, 0.979]
# Mean Relative Root Mean Squared Error: 0.4147
# ======================================================================
# Epoch: 84
# ======================================================================
# Average precision by class: [0.913, 0.851, 0.979, 0.934, 0.869, 0.959]
# Mean Relative Root Mean Squared Error: 0.4326
# ======================================================================
# Epoch: 85
# ======================================================================
# Average precision by class: [0.9, 0.885, 0.989, 0.912, 0.893, 0.964]
# Mean Relative Root Mean Squared Error: 0.4479
# ======================================================================
# Epoch: 86
# ======================================================================
# Average precision by class: [0.905, 0.914, 0.989, 0.946, 0.9, 1.0]
# Mean Relative Root Mean Squared Error: 0.4146
# ======================================================================
# Epoch: 87
# ======================================================================
# Average precision by class: [0.912, 0.97, 0.974, 0.906, 0.881, 0.932]
# Mean Relative Root Mean Squared Error: 0.4439
# ======================================================================
# Epoch: 88
# ======================================================================
# Average precision by class: [0.879, 0.879, 0.995, 0.917, 0.844, 0.99]
# Mean Relative Root Mean Squared Error: 0.4424
# ======================================================================
# Epoch: 89
# ======================================================================
# Average precision by class: [0.904, 0.894, 0.97, 0.88, 0.891, 0.974]
# Mean Relative Root Mean Squared Error: 0.4229
# ======================================================================
# Epoch: 90
# ======================================================================
# Average precision by class: [0.873, 0.93, 0.995, 0.852, 0.918, 0.995]
# Mean Relative Root Mean Squared Error: 0.4313
# ======================================================================
# Epoch: 91
# ======================================================================
# Average precision by class: [0.926, 0.96, 0.97, 0.903, 0.803, 0.984]
# Mean Relative Root Mean Squared Error: 0.4312
# ======================================================================
# Epoch: 92
# ======================================================================
# Average precision by class: [0.949, 0.932, 1.0, 0.853, 0.817, 0.955]
# Mean Relative Root Mean Squared Error: 0.4249
# ======================================================================
# Epoch: 93
# ======================================================================
# Average precision by class: [0.838, 0.917, 1.0, 0.915, 0.881, 0.974]
# Mean Relative Root Mean Squared Error: 0.4336
# ======================================================================
# Epoch: 94
# ======================================================================
# Average precision by class: [0.951, 0.899, 0.975, 0.88, 0.838, 0.995]
# Mean Relative Root Mean Squared Error: 0.4006
# ======================================================================
# Epoch: 95
# ======================================================================
# Average precision by class: [0.91, 0.874, 0.96, 0.898, 0.892, 0.969]
# Mean Relative Root Mean Squared Error: 0.3983
# ======================================================================
# Epoch: 96
# ======================================================================
# Average precision by class: [0.873, 0.888, 0.995, 0.976, 0.867, 0.989]
# Mean Relative Root Mean Squared Error: 0.4514
# ======================================================================
# Epoch: 97
# ======================================================================
# Average precision by class: [0.879, 0.853, 0.995, 0.976, 0.863, 1.0]
# Mean Relative Root Mean Squared Error: 0.4551
# ======================================================================
# Epoch: 98
# ======================================================================
# Average precision by class: [0.877, 0.882, 0.995, 0.945, 0.928, 0.995]
# Mean Relative Root Mean Squared Error: 0.3956
# ======================================================================
# Epoch: 99
# ======================================================================
# Average precision by class: [0.891, 0.92, 0.985, 0.902, 0.914, 1.0]
# Mean Relative Root Mean Squared Error: 0.4461
# ======================================================================
# Epoch: 100
# ======================================================================
# Average precision by class: [0.883, 0.903, 0.995, 0.911, 0.878, 0.989]
# Mean Relative Root Mean Squared Error: 0.4252

# %% [markdown]
# ## Determining Optimal Epoch for Full Train-Validation Training

# %%
from utils import epoch_graphs
epoch_graphs(roc_aucs_by_epoch, mses_by_epoch)

# %% [markdown]
# Average RelRMSE drops until about epoch 40 and then gently falls until around epoch 80, where it starts to become unstable. Average ROC AUC increases quickly until about epoch 20 and then slowly increases until around epoch 80. So, we chose 80 for the number of epochs to train our champion model.

# %% [markdown]
# ## Training on Full Train-Val Dataset

# %%
# Create dataloader
nontest_dataset = ClassifyCountDataset(dataset_type = 'trainval', img_size = 128)
test_dataset = ClassifyCountDataset(dataset_type = 'test', img_size = 128)

nontest_dataloader = DataLoader(nontest_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
torch.manual_seed(2023)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bestmodel1 = VGG16Counting(num_classes=6).to(device)

# %%
champ_num_epochs = 80
save_path = 'drive/MyDrive/SafariNet/Iteration1Test'
os.makedirs(save_path, exist_ok = True)
roc_aucs_on_test, relrmses_on_test = train(bestmodel1, nontest_dataloader,
                                           test_dataloader, num_epochs=champ_num_epochs,
                                           save_path=save_path)
# Out:
# ======================================================================
# Epoch: 1
# ======================================================================
# Average precision by class: [0.821, 0.71, 0.957, 0.848, 0.775, 0.895]
# Mean Relative Root Mean Squared Error: 0.5859
# ======================================================================
# Epoch: 2
# ======================================================================
# Average precision by class: [0.781, 0.706, 0.963, 0.737, 0.812, 0.967]
# Mean Relative Root Mean Squared Error: 0.5325
# ======================================================================
# Epoch: 3
# ======================================================================
# Average precision by class: [0.938, 0.913, 0.979, 0.784, 0.625, 0.975]
# Mean Relative Root Mean Squared Error: 0.5021
# ======================================================================
# Epoch: 4
# ======================================================================
# Average precision by class: [0.724, 0.722, 0.98, 0.893, 0.879, 0.961]
# Mean Relative Root Mean Squared Error: 0.5159
# ======================================================================
# Epoch: 5
# ======================================================================
# Average precision by class: [0.875, 0.876, 0.965, 0.806, 0.786, 0.942]
# Mean Relative Root Mean Squared Error: 0.4632
# ======================================================================
# Epoch: 6
# ======================================================================
# Average precision by class: [0.916, 0.839, 0.98, 0.749, 0.643, 0.975]
# Mean Relative Root Mean Squared Error: 0.4857
# ======================================================================
# Epoch: 7
# ======================================================================
# Average precision by class: [0.84, 0.78, 0.974, 0.865, 0.821, 0.979]
# Mean Relative Root Mean Squared Error: 0.4179
# ======================================================================
# Epoch: 8
# ======================================================================
# Average precision by class: [0.893, 0.809, 0.98, 0.931, 0.791, 1.0]
# Mean Relative Root Mean Squared Error: 0.4144
# ======================================================================
# Epoch: 9
# ======================================================================
# Average precision by class: [0.788, 0.943, 0.985, 0.925, 0.908, 0.99]
# Mean Relative Root Mean Squared Error: 0.3986
# ======================================================================
# Epoch: 10
# ======================================================================
# Average precision by class: [0.912, 0.836, 1.0, 0.851, 0.739, 0.985]
# Mean Relative Root Mean Squared Error: 0.473
# ======================================================================
# Epoch: 11
# ======================================================================
# Average precision by class: [0.965, 0.772, 0.985, 0.938, 0.871, 0.966]
# Mean Relative Root Mean Squared Error: 0.4301
# ======================================================================
# Epoch: 12
# ======================================================================
# Average precision by class: [0.826, 0.968, 0.98, 0.901, 0.862, 0.971]
# Mean Relative Root Mean Squared Error: 0.4346
# ======================================================================
# Epoch: 13
# ======================================================================
# Average precision by class: [0.896, 0.865, 0.99, 0.949, 0.897, 0.975]
# Mean Relative Root Mean Squared Error: 0.4299
# ======================================================================
# Epoch: 14
# ======================================================================
# Average precision by class: [0.859, 0.924, 0.985, 0.817, 0.87, 0.99]
# Mean Relative Root Mean Squared Error: 0.3707
# ======================================================================
# Epoch: 15
# ======================================================================
# Average precision by class: [0.899, 0.949, 0.99, 0.933, 0.856, 0.98]
# Mean Relative Root Mean Squared Error: 0.3998
# ======================================================================
# Epoch: 16
# ======================================================================
# Average precision by class: [0.882, 0.98, 0.985, 0.88, 0.819, 0.943]
# Mean Relative Root Mean Squared Error: 0.3989
# ======================================================================
# Epoch: 17
# ======================================================================
# Average precision by class: [0.937, 0.952, 0.99, 0.763, 0.815, 0.985]
# Mean Relative Root Mean Squared Error: 0.4182
# ======================================================================
# Epoch: 18
# ======================================================================
# Average precision by class: [0.926, 0.935, 0.99, 0.849, 0.825, 0.995]
# Mean Relative Root Mean Squared Error: 0.4026
# ======================================================================
# Epoch: 19
# ======================================================================
# Average precision by class: [0.912, 0.939, 0.975, 0.888, 0.804, 1.0]
# Mean Relative Root Mean Squared Error: 0.4419
# ======================================================================
# Epoch: 20
# ======================================================================
# Average precision by class: [0.888, 0.948, 0.98, 0.878, 0.862, 1.0]
# Mean Relative Root Mean Squared Error: 0.4342
# ======================================================================
# Epoch: 21
# ======================================================================
# Average precision by class: [0.841, 0.961, 0.98, 0.841, 0.927, 0.995]
# Mean Relative Root Mean Squared Error: 0.3937
# ======================================================================
# Epoch: 22
# ======================================================================
# Average precision by class: [0.856, 0.893, 0.99, 0.845, 0.901, 0.99]
# Mean Relative Root Mean Squared Error: 0.44
# ======================================================================
# Epoch: 23
# ======================================================================
# Average precision by class: [0.879, 0.885, 0.985, 0.882, 0.866, 1.0]
# Mean Relative Root Mean Squared Error: 0.4151
# ======================================================================
# Epoch: 24
# ======================================================================
# Average precision by class: [0.888, 0.93, 0.99, 0.881, 0.884, 0.98]
# Mean Relative Root Mean Squared Error: 0.4193
# ======================================================================
# Epoch: 25
# ======================================================================
# Average precision by class: [0.822, 0.97, 0.985, 0.94, 0.898, 0.995]
# Mean Relative Root Mean Squared Error: 0.411
# ======================================================================
# Epoch: 26
# ======================================================================
# Average precision by class: [0.886, 0.959, 0.99, 0.888, 0.879, 1.0]
# Mean Relative Root Mean Squared Error: 0.4512
# ======================================================================
# Epoch: 27
# ======================================================================
# Average precision by class: [0.777, 0.951, 0.985, 0.808, 0.952, 0.995]
# Mean Relative Root Mean Squared Error: 0.4057
# ======================================================================
# Epoch: 28
# ======================================================================
# Average precision by class: [0.908, 0.926, 0.98, 0.775, 0.916, 0.98]
# Mean Relative Root Mean Squared Error: 0.401
# ======================================================================
# Epoch: 29
# ======================================================================
# Average precision by class: [0.907, 0.909, 0.975, 0.932, 0.866, 0.99]
# Mean Relative Root Mean Squared Error: 0.4162
# ======================================================================
# Epoch: 30
# ======================================================================
# Average precision by class: [0.938, 0.95, 0.985, 0.831, 0.862, 0.995]
# Mean Relative Root Mean Squared Error: 0.396
# ======================================================================
# Epoch: 31
# ======================================================================
# Average precision by class: [0.936, 0.843, 0.985, 0.902, 0.88, 0.995]
# Mean Relative Root Mean Squared Error: 0.4284
# ======================================================================
# Epoch: 32
# ======================================================================
# Average precision by class: [0.898, 0.971, 0.995, 0.793, 0.892, 0.99]
# Mean Relative Root Mean Squared Error: 0.43
# ======================================================================
# Epoch: 33
# ======================================================================
# Average precision by class: [0.897, 0.87, 0.995, 0.94, 0.843, 0.99]
# Mean Relative Root Mean Squared Error: 0.4093
# ======================================================================
# Epoch: 34
# ======================================================================
# Average precision by class: [0.928, 0.921, 0.975, 0.834, 0.884, 0.995]
# Mean Relative Root Mean Squared Error: 0.4223
# ======================================================================
# Epoch: 35
# ======================================================================
# Average precision by class: [0.889, 0.941, 0.98, 0.876, 0.863, 0.98]
# Mean Relative Root Mean Squared Error: 0.406
# ======================================================================
# Epoch: 36
# ======================================================================
# Average precision by class: [0.794, 0.906, 0.98, 0.894, 0.914, 1.0]
# Mean Relative Root Mean Squared Error: 0.4355
# ======================================================================
# Epoch: 37
# ======================================================================
# Average precision by class: [0.958, 0.874, 0.995, 0.861, 0.86, 0.99]
# Mean Relative Root Mean Squared Error: 0.4051
# ======================================================================
# Epoch: 38
# ======================================================================
# Average precision by class: [0.885, 0.918, 0.975, 0.88, 0.867, 0.99]
# Mean Relative Root Mean Squared Error: 0.4382
# ======================================================================
# Epoch: 39
# ======================================================================
# Average precision by class: [0.902, 0.976, 0.99, 0.895, 0.848, 0.985]
# Mean Relative Root Mean Squared Error: 0.4286
# ======================================================================
# Epoch: 40
# ======================================================================
# Average precision by class: [0.914, 0.977, 0.995, 0.891, 0.856, 0.98]
# Mean Relative Root Mean Squared Error: 0.4126
# ======================================================================
# Epoch: 41
# ======================================================================
# Average precision by class: [0.905, 0.945, 0.99, 0.88, 0.863, 1.0]
# Mean Relative Root Mean Squared Error: 0.3963
# ======================================================================
# Epoch: 42
# ======================================================================
# Average precision by class: [0.899, 0.964, 0.98, 0.882, 0.856, 0.99]
# Mean Relative Root Mean Squared Error: 0.4101
# ======================================================================
# Epoch: 43
# ======================================================================
# Average precision by class: [0.933, 0.966, 0.995, 0.823, 0.825, 0.985]
# Mean Relative Root Mean Squared Error: 0.4165
# ======================================================================
# Epoch: 44
# ======================================================================
# Average precision by class: [0.942, 0.926, 0.995, 0.883, 0.842, 0.985]
# Mean Relative Root Mean Squared Error: 0.4027
# ======================================================================
# Epoch: 45
# ======================================================================
# Average precision by class: [0.902, 0.922, 0.995, 0.86, 0.878, 0.99]
# Mean Relative Root Mean Squared Error: 0.3976
# ======================================================================
# Epoch: 46
# ======================================================================
# Average precision by class: [0.873, 0.934, 0.995, 0.882, 0.872, 0.995]
# Mean Relative Root Mean Squared Error: 0.4026
# ======================================================================
# Epoch: 47
# ======================================================================
# Average precision by class: [0.902, 0.894, 0.995, 0.894, 0.851, 1.0]
# Mean Relative Root Mean Squared Error: 0.4166
# ======================================================================
# Epoch: 48
# ======================================================================
# Average precision by class: [0.961, 0.885, 0.995, 0.824, 0.843, 0.97]
# Mean Relative Root Mean Squared Error: 0.4492
# ======================================================================
# Epoch: 49
# ======================================================================
# Average precision by class: [0.777, 0.986, 0.975, 0.894, 0.857, 0.995]
# Mean Relative Root Mean Squared Error: 0.4505
# ======================================================================
# Epoch: 50
# ======================================================================
# Average precision by class: [0.856, 0.94, 0.995, 0.893, 0.902, 0.99]
# Mean Relative Root Mean Squared Error: 0.4381
# ======================================================================
# Epoch: 51
# ======================================================================
# Average precision by class: [0.878, 0.895, 0.99, 0.865, 0.928, 0.99]
# Mean Relative Root Mean Squared Error: 0.3954
# ======================================================================
# Epoch: 52
# ======================================================================
# Average precision by class: [0.912, 0.981, 0.985, 0.819, 0.878, 0.995]
# Mean Relative Root Mean Squared Error: 0.4387
# ======================================================================
# Epoch: 53
# ======================================================================
# Average precision by class: [0.908, 0.933, 0.99, 0.855, 0.89, 0.99]
# Mean Relative Root Mean Squared Error: 0.4237
# ======================================================================
# Epoch: 54
# ======================================================================
# Average precision by class: [0.879, 0.945, 0.99, 0.897, 0.901, 0.985]
# Mean Relative Root Mean Squared Error: 0.399
# ======================================================================
# Epoch: 55
# ======================================================================
# Average precision by class: [0.926, 0.904, 0.985, 0.867, 0.912, 0.995]
# Mean Relative Root Mean Squared Error: 0.3928
# ======================================================================
# Epoch: 56
# ======================================================================
# Average precision by class: [0.91, 0.915, 0.99, 0.833, 0.918, 1.0]
# Mean Relative Root Mean Squared Error: 0.4373
# ======================================================================
# Epoch: 57
# ======================================================================
# Average precision by class: [0.904, 0.95, 0.995, 0.882, 0.936, 0.99]
# Mean Relative Root Mean Squared Error: 0.4227
# ======================================================================
# Epoch: 58
# ======================================================================
# Average precision by class: [0.927, 0.93, 0.99, 0.834, 0.911, 0.985]
# Mean Relative Root Mean Squared Error: 0.4359
# ======================================================================
# Epoch: 59
# ======================================================================
# Average precision by class: [0.88, 0.953, 0.99, 0.895, 0.825, 0.995]
# Mean Relative Root Mean Squared Error: 0.4095
# ======================================================================
# Epoch: 60
# ======================================================================
# Average precision by class: [0.893, 0.844, 0.995, 0.812, 0.926, 1.0]
# Mean Relative Root Mean Squared Error: 0.4298
# ======================================================================
# Epoch: 61
# ======================================================================
# Average precision by class: [0.957, 0.945, 0.98, 0.766, 0.819, 1.0]
# Mean Relative Root Mean Squared Error: 0.4079
# ======================================================================
# Epoch: 62
# ======================================================================
# Average precision by class: [0.873, 0.951, 0.99, 0.894, 0.929, 0.99]
# Mean Relative Root Mean Squared Error: 0.4177
# ======================================================================
# Epoch: 63
# ======================================================================
# Average precision by class: [0.933, 0.883, 0.99, 0.895, 0.874, 1.0]
# Mean Relative Root Mean Squared Error: 0.3914
# ======================================================================
# Epoch: 64
# ======================================================================
# Average precision by class: [0.916, 0.9, 0.995, 0.907, 0.854, 1.0]
# Mean Relative Root Mean Squared Error: 0.4105
# ======================================================================
# Epoch: 65
# ======================================================================
# Average precision by class: [0.892, 0.871, 0.995, 0.891, 0.94, 0.995]
# Mean Relative Root Mean Squared Error: 0.4067
# ======================================================================
# Epoch: 66
# ======================================================================
# Average precision by class: [0.92, 0.932, 1.0, 0.875, 0.876, 0.938]
# Mean Relative Root Mean Squared Error: 0.4406
# ======================================================================
# Epoch: 67
# ======================================================================
# Average precision by class: [0.89, 0.964, 0.98, 0.924, 0.877, 1.0]
# Mean Relative Root Mean Squared Error: 0.4193
# ======================================================================
# Epoch: 68
# ======================================================================
# Average precision by class: [0.935, 0.961, 0.99, 0.826, 0.875, 0.99]
# Mean Relative Root Mean Squared Error: 0.4245
# ======================================================================
# Epoch: 69
# ======================================================================
# Average precision by class: [0.906, 0.909, 0.985, 0.844, 0.901, 0.985]
# Mean Relative Root Mean Squared Error: 0.4456
# ======================================================================
# Epoch: 70
# ======================================================================
# Average precision by class: [0.923, 0.895, 0.995, 0.871, 0.876, 0.99]
# Mean Relative Root Mean Squared Error: 0.4308
# ======================================================================
# Epoch: 71
# ======================================================================
# Average precision by class: [0.86, 0.919, 0.985, 0.907, 0.912, 0.985]
# Mean Relative Root Mean Squared Error: 0.4471
# ======================================================================
# Epoch: 72
# ======================================================================
# Average precision by class: [0.898, 0.994, 0.995, 0.836, 0.822, 0.99]
# Mean Relative Root Mean Squared Error: 0.3991
# ======================================================================
# Epoch: 73
# ======================================================================
# Average precision by class: [0.911, 0.925, 0.985, 0.894, 0.872, 0.99]
# Mean Relative Root Mean Squared Error: 0.41
# ======================================================================
# Epoch: 74
# ======================================================================
# Average precision by class: [0.913, 0.976, 1.0, 0.829, 0.891, 0.99]
# Mean Relative Root Mean Squared Error: 0.4045
# ======================================================================
# Epoch: 75
# ======================================================================
# Average precision by class: [0.877, 0.893, 0.966, 0.902, 0.948, 0.995]
# Mean Relative Root Mean Squared Error: 0.4219
# ======================================================================
# Epoch: 76
# ======================================================================
# Average precision by class: [0.92, 0.892, 0.985, 0.878, 0.902, 0.995]
# Mean Relative Root Mean Squared Error: 0.4167
# ======================================================================
# Epoch: 77
# ======================================================================
# Average precision by class: [0.859, 0.954, 0.99, 0.864, 0.901, 0.99]
# Mean Relative Root Mean Squared Error: 0.4183
# ======================================================================
# Epoch: 78
# ======================================================================
# Average precision by class: [0.923, 0.927, 0.975, 0.892, 0.868, 1.0]
# Mean Relative Root Mean Squared Error: 0.3862
# ======================================================================
# Epoch: 79
# ======================================================================
# Average precision by class: [0.877, 0.93, 0.985, 0.88, 0.928, 0.99]
# Mean Relative Root Mean Squared Error: 0.4083
# ======================================================================
# Epoch: 80
# ======================================================================
# Average precision by class: [0.893, 0.925, 0.995, 0.908, 0.897, 0.98]
# Mean Relative Root Mean Squared Error: 0.4273

# %%
from utils import display_results
# Displaying Test Scores
final_relrmses = relrmses_on_test[champ_num_epochs - 1, :]
final_roc_aucs = roc_aucs_on_test[champ_num_epochs - 1, :]
display_results(final_relrmses, final_roc_aucs)
# Out:
# RelRMSE = 0.35  &  AUROC = 0.93  <--  giraffe_reticulated
# RelRMSE = 0.55  &  AUROC = 0.95  <--  zebra_grevys
# RelRMSE = 0.09  &  AUROC = 0.99  <--  turtle_sea
# RelRMSE = 1.02  &  AUROC = 0.84  <--  zebra_plains
# RelRMSE = 0.45  &  AUROC = 0.87  <--  giraffe_masai
# RelRMSE = 0.1  &  AUROC = 0.99  <--  whale_fluke
# RelRMSE = 0.43  &  AUROC = 0.93  <--  average
